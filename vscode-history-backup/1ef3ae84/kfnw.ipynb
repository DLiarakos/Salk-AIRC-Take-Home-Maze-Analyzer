# %% [markdown]
# # Initial Steps: load packages, files and functions

# %%
import json, re, time, itertools
from copy import deepcopy
from pathlib import Path
from datetime import datetime
import os
import pandas as pd
import requests

# %%
cwd=os.getcwd()
cwd_Raw_Data_outputs=os.path.join(cwd,'RawData')#heres where we store freezes of the raw data
# cwd_Figures=os.path.join(cwd,'Figures')#figures and code for generating them can go here
cwd_Output=os.path.join(cwd,'Output Dataframes')

# %%
def GetAwardAmount(input_String, Lists):
    #function takes three arguments; the Reporter output, the destination where we store results, and an additional list for storing a freeze of the data
    GetResults = input_String.find("\"results\"") #find the part of the output detailing grant award amount, found after the "results" block of the ouput
    ResultsList = input_String[GetResults:].replace("},", "")# each grant's information is separated by curly brackets; splitting along curly brackets divides info from each grant
    ResultsList = (ResultsList.split("{\""))[1:]    #saving the individual grant amount as a an element in a list of grants
    for iGrant in ResultsList:# for each grant returned by the query
        Award_Start = iGrant.find("\"award_amount\":")#find the part detailing award amount
        Award_End = iGrant.find("\"project_start_date\":")#find the part that comes after the award amount
        DirectCost = iGrant.find("\"direct_cost_amt\":")
        direct_End = iGrant.find("\"indirect_cost_amt\":")
        Award_string = iGrant[Award_Start:Award_End].replace(",", "").split(":")[1]# the amount of money for grant will be between the part addressed as award amount and the direct cost amount
        directCost = iGrant[DirectCost:direct_End].replace(",", "").split(':', 1)[1]
        indirectCost = iGrant[direct_End:].replace(",", "").split(':', 1)[1]
        if not Award_string == "null": # for some reason, some grants do not have an award amount stored in NIH Reporter
            Lists[0] = Lists[0] + int(Award_string)
            if not directCost == "null":
                Lists[1]=Lists[1]+int(directCost)
            if not "null" in indirectCost:
                indirectCost=indirectCost.replace("}]}","")
                Lists[2]=Lists[2]+int(indirectCost)
    return Lists

# %%
xlsx_path = Path("ShortMeeting history.xlsx")  # <-- change if needed

# Read sheets (your first sheet name is a bit odd, so grab by index)
xls = pd.ExcelFile(xlsx_path)
participants_df = pd.read_excel(xlsx_path, sheet_name=xls.sheet_names[0])
meetings_df      = pd.read_excel(xlsx_path, sheet_name="Meetings")

participants_df.iloc[ 1:2] = "Targeting Lipid Biology in Cancer"
participants_df.tail(5)
# Out:
#                  Participant               Meeting     Type First Name  \
# 54          Elsa Flores, PhD  2005 Scholar Retreat  Scholar       Elsa
# 55  Kimryn Rathmell, MD, PhD  2005 Scholar Retreat  Scholar     Kimryn
# 56   Masashi Narita, MD, PhD  2005 Scholar Retreat  Scholar    Masashi
# 57        Jan Karlseder, PhD  2005 Scholar Retreat  Scholar        Jan
# 58   James Amatruda, MD, PhD  2005 Scholar Retreat  Scholar      James
#
#     Last Name   Suffix                             Institution Title
# 54     Flores      PhD               MD Anderson Cancer Center   NaN
# 55   Rathmell  MD, PhD    Vanderbilt University Medical Center   NaN
# 56     Narita  MD, PhD                     Cambridge Institute   NaN
# 57  Karlseder      PhD                          Salk Institute   NaN
# 58   Amatruda  MD, PhD  Memorial Sloan Kettering Cancer Center   NaN

# %%
# Cell 2 — helpers (normalize meeting titles + parse chair names)

def normalize_meeting_title(x: str) -> str:
    """
    Make meeting titles comparable across sheets:
    - cast to str
    - strip leading/trailing whitespace
    - remove surrounding quotes
    - collapse internal whitespace (including newlines)
    """
    if pd.isna(x):
        return None
    s = str(x).strip()
    # remove one pair of surrounding quotes if present
    if (len(s) >= 2) and ((s[0] == s[-1]) and s[0] in {"'", '"'}):
        s = s[1:-1].strip()
    s = re.sub(r"\s+", " ", s)  # collapse newlines/tabs/multiple spaces
    return s

def split_chair_names(chairs_cell) -> list[str]:
    """
    Turn the 'Meeting Chairs' cell into a list of chair name strings.
    Handles separators like ';', ',', ' and ', '&', and common ' of ' patterns.
    Keeps credentials as part of the name string (e.g., 'MD, PhD').
    """
    if pd.isna(chairs_cell):
        return []
    s = str(chairs_cell).strip()
    s = re.sub(r"\s+", " ", s)

    # Many entries look like "Name of Institution; Name of Institution"
    # Split primarily on ';' first.
    parts = [p.strip() for p in s.split(";") if p.strip()]

    # Further split each part on " and " / " & " if it contains multiple chairs.
    chairs = []
    for p in parts:
        sub = re.split(r"\s+(?:and|&)\s+", p)
        for item in sub:
            item = item.strip()
            if not item:
                continue
            # Remove trailing institution phrase like " of XYZ" (optional, but helps matching)
            item = re.sub(r"\s+of\s+.+$", "", item).strip()
            chairs.append(item)

    # de-dup while preserving order
    seen = set()
    out = []
    for c in chairs:
        if c not in seen:
            seen.add(c)
            out.append(c)
    return out

# %%
meetings_df = meetings_df.copy()
participants_df = participants_df.copy()

meetings_df["MeetingTopic_norm"] = meetings_df["Meeting Topic"].map(normalize_meeting_title)
participants_df["Meeting_norm"]  = participants_df["Meeting"].map(normalize_meeting_title)

# Map normalized meeting topic -> year (if duplicates exist, keep the first non-null year)
meeting_to_year = (
    meetings_df.dropna(subset=["MeetingTopic_norm", "Year"])
               .drop_duplicates(subset=["MeetingTopic_norm"])
               .set_index("MeetingTopic_norm")["Year"]
               .to_dict()
)

# Attach year onto participants using normalized title
participants_df["Year"] = participants_df["Meeting_norm"].map(meeting_to_year)

participants_df[["Participant", "Meeting", "Year"]]
# Out:
#                           Participant  \
# 0                  Alison Ringel, PhD
# 1   Targeting Lipid Biology in Cancer
# 2            Bart Vanhaesebroeck, PhD
# 3      Christina Mitchell, MB BS, PhD
# 4                 Neil Vasan, MD, PhD
# 5       Prof Banafshe  Larijani , PhD
# 6                         Ray Blind,
# 7                Brooke Emerling, PhD
# 8                Gretchen Alicea, PhD
# 9                      Sarah  Skuli,
# 10                  David Fruman, PhD
# 11                Hua Eleanor Yu, PhD
# 12               Vytas Bankaitis, PhD
# 13                 Jeremy Baskin, PhD
# 14                 Emilio Hirsch, PhD
# 15               Tamas Balla, MD, PhD
# 16    Livia  Schiavinato Eberlin, PhD
# 17                      Karen Dixon,
# 18             Tomi Pastinen, MD, PhD
# 19             Laura Banaszynski, PhD
# 20            Leonid Mirny, PhD, M.Sc
# 21                     Jane Skok, PhD
# 22                      Denes Hnisz,
# 23                    Ari Melnick, MD
# 24                Mathieu Lupien, PhD
# 25               Jan-Michael Peters,
# 26                     Brian Huntly,
# 27                      Bing Ren, PhD
# 28                  Kathleen Xie, PhD
# 29                     Ting Wang, PhD
# 30                   Francois Spitz,
# 31                  Martin Rivas, PhD
# 32                Clodagh O'Shea, PhD
# 33                   Danfeng Cai, PhD
# 34               Gerd Blobel, MD, PhD
# 35                     Elphege Nora,
# 36                Peter Scacheri, PhD
# 37                  Di Zhang, MD, PhD
# 38                    John Kemshead,
# 39                 Benjamin Rowland,
# 40                      Peter Ly, PhD
# 41            Eftychia Apostolou, PhD
# 42           David E. Fisher, MD, PhD
# 43                    Scott Lowe, PhD
# 44             Charles L. Sawyers, MD
# 45             Charles Sherr, MD, PhD
# 46                 Craig Thompson, MD
# 47             David Tuveson, MD, PhD
# 48         Christopher Bakkenist, PhD
# 49                 Edward Attiyeh, MD
# 50             Anthony Letai, MD, PhD
# 51            Alison Bertuch, MD, PhD
# 52               Norman Sharpless, MD
# 53               Nabeel Bardeesy, PhD
# 54                   Elsa Flores, PhD
# 55           Kimryn Rathmell, MD, PhD
# 56            Masashi Narita, MD, PhD
# 57                 Jan Karlseder, PhD
# 58            James Amatruda, MD, PhD
#
#                                              Meeting  Year
# 0                 Targeting Lipid Biology in Cancer   2023
# 1                  Targeting Lipid Biology in Cancer  2023
# 2                 Targeting Lipid Biology in Cancer   2023
# 3                 Targeting Lipid Biology in Cancer   2023
# 4                 Targeting Lipid Biology in Cancer   2023
# 5                 Targeting Lipid Biology in Cancer   2023
# 6                 Targeting Lipid Biology in Cancer   2023
# 7                 Targeting Lipid Biology in Cancer   2023
# 8                 Targeting Lipid Biology in Cancer   2023
# 9                 Targeting Lipid Biology in Cancer   2023
# 10                Targeting Lipid Biology in Cancer   2023
# 11                Targeting Lipid Biology in Cancer   2023
# 12                Targeting Lipid Biology in Cancer   2023
# 13                Targeting Lipid Biology in Cancer   2023
# 14                Targeting Lipid Biology in Cancer   2023
# 15                Targeting Lipid Biology in Cancer   2023
# 16                Targeting Lipid Biology in Cancer   2023
# 17                Targeting Lipid Biology in Cancer   2023
# 18  3D Chromosomal Architecture and Nuclear Topology  2019
# 19  3D Chromosomal Architecture and Nuclear Topology  2019
# 20  3D Chromosomal Architecture and Nuclear Topology  2019
# 21  3D Chromosomal Architecture and Nuclear Topology  2019
# 22  3D Chromosomal Architecture and Nuclear Topology  2019
# 23  3D Chromosomal Architecture and Nuclear Topology  2019
# 24  3D Chromosomal Architecture and Nuclear Topology  2019
# 25  3D Chromosomal Architecture and Nuclear Topology  2019
# 26  3D Chromosomal Architecture and Nuclear Topology  2019
# 27  3D Chromosomal Architecture and Nuclear Topology  2019
# 28  3D Chromosomal Architecture and Nuclear Topology  2019
# 29  3D Chromosomal Architecture and Nuclear Topology  2019
# 30  3D Chromosomal Architecture and Nuclear Topology  2019
# 31  3D Chromosomal Architecture and Nuclear Topology  2019
# 32  3D Chromosomal Architecture and Nuclear Topology  2019
# 33  3D Chromosomal Architecture and Nuclear Topology  2019
# 34  3D Chromosomal Architecture and Nuclear Topology  2019
# 35  3D Chromosomal Architecture and Nuclear Topology  2019
# 36  3D Chromosomal Architecture and Nuclear Topology  2019
# 37  3D Chromosomal Architecture and Nuclear Topology  2019
# 38  3D Chromosomal Architecture and Nuclear Topology  2019
# 39  3D Chromosomal Architecture and Nuclear Topology  2019
# 40  3D Chromosomal Architecture and Nuclear Topology  2019
# 41  3D Chromosomal Architecture and Nuclear Topology  2019
# 42                              2005 Scholar Retreat  2005
# 43                              2005 Scholar Retreat  2005
# 44                              2005 Scholar Retreat  2005
# 45                              2005 Scholar Retreat  2005
# 46                              2005 Scholar Retreat  2005
# 47                              2005 Scholar Retreat  2005
# 48                              2005 Scholar Retreat  2005
# 49                              2005 Scholar Retreat  2005
# 50                              2005 Scholar Retreat  2005
# 51                              2005 Scholar Retreat  2005
# 52                              2005 Scholar Retreat  2005
# 53                              2005 Scholar Retreat  2005
# 54                              2005 Scholar Retreat  2005
# 55                              2005 Scholar Retreat  2005
# 56                              2005 Scholar Retreat  2005
# 57                              2005 Scholar Retreat  2005
# 58                              2005 Scholar Retreat  2005

# %%
# Cell 4 — (1) create dict keyed by "Meeting Topic (Year)" with list of participant full names

# Keep only rows that have a meeting + participant name
p = participants_df.dropna(subset=["Meeting_norm", "Participant"]).copy()

# Build a key string like "Targeting Lipid Biology in Cancer (2021)"
def make_meeting_year_key(meeting_norm, year):
    y = "" if pd.isna(year) else str(int(year)) if float(year).is_integer() else str(year)
    return f"{meeting_norm} ({y})" if y else f"{meeting_norm} (Year Unknown)"

p["MeetingYearKey"] = [make_meeting_year_key(m, y) for m, y in zip(p["Meeting_norm"], p["Year"])]

meeting_attendees_dict = (
    p.groupby("MeetingYearKey")["Participant"]
     .apply(lambda s: sorted(set(s.dropna().astype(str).str.strip())))
     .to_dict()
)

# Example: show first 5 keys
list(meeting_attendees_dict["Targeting Lipid Biology in Cancer (2023)"])
# Out:
# ['Alison Ringel, PhD',
#  'Bart Vanhaesebroeck, PhD',
#  'Brooke Emerling, PhD',
#  'Christina Mitchell, MB BS, PhD',
#  'David Fruman, PhD',
#  'Emilio Hirsch, PhD',
#  'Gretchen Alicea, PhD',
#  'Hua Eleanor Yu, PhD',
#  'Jeremy Baskin, PhD',
#  'Karen Dixon,',
#  'Livia  Schiavinato Eberlin, PhD',
#  'Neil Vasan, MD, PhD',
#  'Prof Banafshe  Larijani , PhD',
#  'Ray Blind,',
#  'Sarah  Skuli,',
#  'Tamas Balla, MD, PhD',
#  'Targeting Lipid Biology in Cancer',
#  'Vytas Bankaitis, PhD']

# %%
REPORTER_SEARCH_URL = "https://api.reporter.nih.gov/v2/projects/search"
_SUFFIXES = {"jr","sr","ii","iii","iv","md","phd","mph","ms","m.d.","ph.d.","dr"}

def parse_first_last(name):
    if not name: return "", ""
    s = re.sub(r"\([^)]*\)", "", str(name))
    s = re.sub(r"^(dr\.?|prof\.?)\s+", "", s.strip(), flags=re.I)
    parts = [p.strip() for p in s.split(",") if p.strip()]
    if len(parts) >= 2:
        last, first = parts[0], (parts[1].split()[0] if parts[1] else "")
        return first.lower(), last.lower()
    toks = [t for t in s.split() if t.lower().strip(".") not in _SUFFIXES]
    if len(toks) == 1: return "", toks[0].lower()
    return toks[0].lower(), toks[-1].lower()

def pi_entry(name):
    first, last = parse_first_last(name)
    if not last: return None
    return {"any_name": last, "first_name": first}

def meeting_year_from_key(meeting_key):
    m = re.search(r"\((\d{4})\)\s*$", str(meeting_key))
    return int(m.group(1)) if m else None

def five_year_bins(center_year, n_bins_before=1, n_bins_after=3):
    return ([(center_year-5*i, center_year-5*(i-1)) for i in range(n_bins_before, 0, -1)] +
            [(center_year+5*i, center_year+5*(i+1)) for i in range(0, n_bins_after)])

def fiscal_years_for_bin(start, end):
    return list(range(int(start), int(end) + 1))

def reporter_search_all_pages(payload, sleep=0.25, limit=500):
    params = deepcopy(payload); params.update({"offset": 0, "limit": limit})
    pages, total = [], None
    while True:
        r = requests.post(REPORTER_SEARCH_URL, json=params, timeout=60)
        r.raise_for_status()
        page = r.json(); pages.append(page)
        total = total or page.get("meta", {}).get("total", 0)
        off = page.get("meta", {}).get("offset", params["offset"])
        cnt = page.get("meta", {}).get("count", len(page.get("results", [])))
        if cnt == 0 or off + cnt >= total: break
        params["offset"] = off + cnt
        time.sleep(sleep)
    return {"total": int(total or 0), "pages": pages}

def multi_pi_collab_by_meeting(
    meeting_attendees_dict,
    NIH_param_template,
    n_bins_before=1,
    n_bins_after=3,
    sleep=0.25,
    print_every_n_pairs=200,   # set None to disable periodic progress prints
):
    summary_rows, detail_rows = [], []
    print("\n=== START MULTI-PI COLLAB ANALYSIS (DEDUP BY appl_id PER BIN) ===")

    for meeting_key, names in meeting_attendees_dict.items():
        print("\n===================================================")
        print(f"Meeting: {meeting_key}")
        print(f"Attendees in dict: {len(names)}")

        year = meeting_year_from_key(meeting_key)
        if year is None:
            print("  ⚠ No year found in meeting key; skipping.")
            continue
        print(f"Meeting year: {year}")

        clean = [(n, pi_entry(n)) for n in names]
        clean = [(n, e) for (n, e) in clean if e is not None]
        print(f"Parsable PI-like names: {len(clean)}")
        if len(clean) < 2:
            print("  ⚠ <2 parsable names; skipping meeting.")
            continue

        pairs = list(itertools.combinations(clean, 2))
        print(f"PI pairs to test: {len(pairs)}")

        for start, end in five_year_bins(year, n_bins_before, n_bins_after):
            print("\n-----------------------------------------------")
            print(f"Bin: {start}–{end}")
            fys = fiscal_years_for_bin(start, end)
            print(f"Fiscal years: {fys[0]}..{fys[-1]}")

            # Key change: dedupe at appl_id level per bin
            seen_appl_ids = set()
            unique_award_amount_sum = 0
            pair_hits = 0
            pair_idx = 0

            for (name_a, pi_a), (name_b, pi_b) in pairs:
                pair_idx += 1
                if print_every_n_pairs and pair_idx % print_every_n_pairs == 0:
                    print(f"  Progress: tested {pair_idx}/{len(pairs)} pairs; unique appl_ids so far: {len(seen_appl_ids)}")

                payload = deepcopy(NIH_param_template)
                payload.setdefault("criteria", {})
                c = payload["criteria"]
                c["pi_names"] = [pi_a, pi_b]
                c["multi_pi_only"] = True
                c["fiscal_years"] = fys
                c.pop("advanced_text_search", None)  # PI-only

                payload["include_fields"] = [
                    "appl_id","subproject_id","fiscal_year","project_num","project_title",
                    "fy_total_cost","award_amount","principal_investigators"
                ]

                res = reporter_search_all_pages(payload, sleep=sleep)
                if res["total"] <= 0:
                    continue

                pair_hits += 1
                pair_label = f"{name_a} || {name_b}"
                print(f"  Pair hit: {pair_label} -> {res['total']} records")

                # Record details, but mark whether the appl_id is first-seen in this bin
                for page in res["pages"]:
                    print("results")
                    print(page.get("results"))
                    for proj in page.get("results", []):
                        appl = proj.get("appl_id")
                        subp = proj.get("subproject_id")
                        fy = proj.get("fiscal_year")
                        pnum = proj.get("project_num")
                        title = proj.get("project_title")
                        cost = proj.get("fy_total_cost") if proj.get("fy_total_cost") is not None else proj.get("award_amount")
                        cost = int(cost or 0)

                        first_seen = appl not in seen_appl_ids
                        detail_rows.append({
                            "MeetingYearKey": meeting_key,
                            "Bin": f"{start}-{end}",
                            "Pair": pair_label,
                            "ApplId": appl,
                            "SubprojectId": subp,
                            "FiscalYear": fy,
                            "ProjectNum": pnum,
                            "ProjectTitle": title,
                            "AwardAmount": cost,
                            "IsFirstSeenInBin": first_seen,
                            "PrincipalInvestigators_raw": proj.get("principal_investigators")
                        })

                        # Dedup per bin: only count appl_id once
                        if first_seen:
                            seen_appl_ids.add(appl)
                            unique_award_amount_sum += cost

                time.sleep(sleep)

            print("\nBIN SUMMARY")
            print(f"  Pairs with ≥1 result: {pair_hits}")
            print(f"  Unique appl_ids in bin: {len(seen_appl_ids)}")
            print(f"  Summed award amount (unique appl_id only): ${unique_award_amount_sum:,}")

            summary_rows.append({
                "MeetingYearKey": meeting_key,
                "MeetingYear": year,
                "Bin": f"{start}-{end}",
                "Pairs_tested": len(pairs),
                "Pairs_with_hits": pair_hits,
                "Unique_appl_ids": len(seen_appl_ids),
                "Unique_award_amount_sum": unique_award_amount_sum
            })

    print("\n=== COMPLETE ===")
    return pd.DataFrame(summary_rows), pd.DataFrame(detail_rows)

# %%
NIH_param={"criteria": {}}
NIH_param = {"criteria": {}}
summary_df, details_df = multi_pi_collab_by_meeting(
    meeting_attendees_dict,
    NIH_param_template=NIH_param,
    n_bins_before=1,
    n_bins_after=3,
    sleep=0.25,
    print_every_n_pairs=200
)
summary_df.sort_values(["MeetingYearKey","Bin"]).head(20)
# Out:
# === START MULTI-PI COLLAB ANALYSIS (DEDUP BY appl_id PER BIN) ===
#
# ===================================================
# Meeting: 2005 Scholar Retreat (2005)
# Attendees in dict: 17
# Meeting year: 2005
# Parsable PI-like names: 17
# PI pairs to test: 136
#
# -----------------------------------------------
# Bin: 2000–2005
# Fiscal years: 2000..2005
#
# BIN SUMMARY
#   Pairs with ≥1 result: 0
#   Unique appl_ids in bin: 0
#   Summed award amount (unique appl_id only): $0
#
# -----------------------------------------------
# Bin: 2005–2010
# Fiscal years: 2005..2010
#   Pair hit: Alison Bertuch, MD, PhD || James Amatruda, MD, PhD -> 2 records
#   Pair hit: Alison Bertuch, MD, PhD || Nabeel Bardeesy, PhD -> 2 records
#   Pair hit: Anthony Letai, MD, PhD || James Amatruda, MD, PhD -> 2 records
#   Pair hit: Anthony Letai, MD, PhD || Nabeel Bardeesy, PhD -> 2 records
#   Pair hit: Charles L. Sawyers, MD || James Amatruda, MD, PhD -> 2 records
#   Pair hit: Charles L. Sawyers, MD || Nabeel Bardeesy, PhD -> 2 records
#   Pair hit: Charles Sherr, MD, PhD || James Amatruda, MD, PhD -> 2 records
#   Pair hit: Charles Sherr, MD, PhD || Nabeel Bardeesy, PhD -> 2 records
#   Pair hit: Christopher Bakkenist, PhD || James Amatruda, MD, PhD -> 2 records
#   Pair hit: Christopher Bakkenist, PhD || Nabeel Bardeesy, PhD -> 2 records
#   Pair hit: Craig Thompson, MD || James Amatruda, MD, PhD -> 2 records
#   Pair hit: Craig Thompson, MD || Nabeel Bardeesy, PhD -> 2 records
#   Pair hit: David E. Fisher, MD, PhD || James Amatruda, MD, PhD -> 2 records
#   Pair hit: David E. Fisher, MD, PhD || Nabeel Bardeesy, PhD -> 2 records
#   Pair hit: David Tuveson, MD, PhD || James Amatruda, MD, PhD -> 2 records
#   Pair hit: David Tuveson, MD, PhD || Nabeel Bardeesy, PhD -> 2 records
#   Pair hit: Edward Attiyeh, MD || James Amatruda, MD, PhD -> 2 records
#   Pair hit: Edward Attiyeh, MD || Nabeel Bardeesy, PhD -> 2 records
#   Pair hit: Elsa Flores, PhD || James Amatruda, MD, PhD -> 2 records
#   Pair hit: Elsa Flores, PhD || Nabeel Bardeesy, PhD -> 2 records
#   Pair hit: James Amatruda, MD, PhD || Jan Karlseder, PhD -> 2 records
#   Pair hit: James Amatruda, MD, PhD || Kimryn Rathmell, MD, PhD -> 2 records
#   Pair hit: James Amatruda, MD, PhD || Masashi Narita, MD, PhD -> 2 records
#   Pair hit: James Amatruda, MD, PhD || Nabeel Bardeesy, PhD -> 4 records
#   Pair hit: James Amatruda, MD, PhD || Norman Sharpless, MD -> 2 records
#   Pair hit: James Amatruda, MD, PhD || Scott Lowe, PhD -> 2 records
#   Pair hit: Jan Karlseder, PhD || Nabeel Bardeesy, PhD -> 2 records
#   Pair hit: Kimryn Rathmell, MD, PhD || Nabeel Bardeesy, PhD -> 2 records
#   Pair hit: Masashi Narita, MD, PhD || Nabeel Bardeesy, PhD -> 2 records
#   Pair hit: Nabeel Bardeesy, PhD || Norman Sharpless, MD -> 2 records
#   Pair hit: Nabeel Bardeesy, PhD || Scott Lowe, PhD -> 2 records
#
# BIN SUMMARY
#   Pairs with ≥1 result: 31
#   Unique appl_ids in bin: 1
#   Summed award amount (unique appl_id only): $0
#
# -----------------------------------------------
# Bin: 2010–2015
# Fiscal years: 2010..2015
#   Pair hit: Alison Bertuch, MD, PhD || Craig Thompson, MD -> 2 records
#   Pair hit: Alison Bertuch, MD, PhD || David Tuveson, MD, PhD -> 2 records
#   Pair hit: Alison Bertuch, MD, PhD || James Amatruda, MD, PhD -> 3 records
#   Pair hit: Alison Bertuch, MD, PhD || Kimryn Rathmell, MD, PhD -> 2 records
#   Pair hit: Alison Bertuch, MD, PhD || Nabeel Bardeesy, PhD -> 9 records
#   Pair hit: Alison Bertuch, MD, PhD || Norman Sharpless, MD -> 6 records
#   Pair hit: Alison Bertuch, MD, PhD || Scott Lowe, PhD -> 5 records
#   Pair hit: Anthony Letai, MD, PhD || Craig Thompson, MD -> 2 records
#   Pair hit: Anthony Letai, MD, PhD || David Tuveson, MD, PhD -> 2 records
#   Pair hit: Anthony Letai, MD, PhD || James Amatruda, MD, PhD -> 3 records
#   Pair hit: Anthony Letai, MD, PhD || Kimryn Rathmell, MD, PhD -> 2 records
#   Pair hit: Anthony Letai, MD, PhD || Nabeel Bardeesy, PhD -> 9 records
#   Pair hit: Anthony Letai, MD, PhD || Norman Sharpless, MD -> 6 records
#   Pair hit: Anthony Letai, MD, PhD || Scott Lowe, PhD -> 5 records
#   Pair hit: Charles L. Sawyers, MD || Craig Thompson, MD -> 2 records
#   Pair hit: Charles L. Sawyers, MD || David Tuveson, MD, PhD -> 2 records
#   Pair hit: Charles L. Sawyers, MD || James Amatruda, MD, PhD -> 3 records
#   Pair hit: Charles L. Sawyers, MD || Kimryn Rathmell, MD, PhD -> 2 records
#   Pair hit: Charles L. Sawyers, MD || Nabeel Bardeesy, PhD -> 9 records
#   Pair hit: Charles L. Sawyers, MD || Norman Sharpless, MD -> 6 records
#   Pair hit: Charles L. Sawyers, MD || Scott Lowe, PhD -> 5 records
#   Pair hit: Charles Sherr, MD, PhD || Craig Thompson, MD -> 2 records
#   Pair hit: Charles Sherr, MD, PhD || David Tuveson, MD, PhD -> 2 records
#   Pair hit: Charles Sherr, MD, PhD || James Amatruda, MD, PhD -> 3 records
#   Pair hit: Charles Sherr, MD, PhD || Kimryn Rathmell, MD, PhD -> 2 records
#   Pair hit: Charles Sherr, MD, PhD || Nabeel Bardeesy, PhD -> 9 records
#   Pair hit: Charles Sherr, MD, PhD || Norman Sharpless, MD -> 6 records
#   Pair hit: Charles Sherr, MD, PhD || Scott Lowe, PhD -> 5 records
#   Pair hit: Christopher Bakkenist, PhD || Craig Thompson, MD -> 2 records
#   Pair hit: Christopher Bakkenist, PhD || David Tuveson, MD, PhD -> 2 records
#   Pair hit: Christopher Bakkenist, PhD || James Amatruda, MD, PhD -> 3 records
#   Pair hit: Christopher Bakkenist, PhD || Kimryn Rathmell, MD, PhD -> 2 records
#   Pair hit: Christopher Bakkenist, PhD || Nabeel Bardeesy, PhD -> 9 records
#   Pair hit: Christopher Bakkenist, PhD || Norman Sharpless, MD -> 6 records
#   Pair hit: Christopher Bakkenist, PhD || Scott Lowe, PhD -> 5 records
#   Pair hit: Craig Thompson, MD || David E. Fisher, MD, PhD -> 2 records
#   Pair hit: Craig Thompson, MD || David Tuveson, MD, PhD -> 4 records
#   Pair hit: Craig Thompson, MD || Edward Attiyeh, MD -> 2 records
#   Pair hit: Craig Thompson, MD || Elsa Flores, PhD -> 2 records
#   Pair hit: Craig Thompson, MD || James Amatruda, MD, PhD -> 5 records
#   Pair hit: Craig Thompson, MD || Jan Karlseder, PhD -> 2 records
#   Pair hit: Craig Thompson, MD || Kimryn Rathmell, MD, PhD -> 4 records
#   Pair hit: Craig Thompson, MD || Masashi Narita, MD, PhD -> 2 records
#   Pair hit: Craig Thompson, MD || Nabeel Bardeesy, PhD -> 11 records
#   Pair hit: Craig Thompson, MD || Norman Sharpless, MD -> 8 records
#   Pair hit: Craig Thompson, MD || Scott Lowe, PhD -> 7 records
#   Pair hit: David E. Fisher, MD, PhD || David Tuveson, MD, PhD -> 2 records
#   Pair hit: David E. Fisher, MD, PhD || James Amatruda, MD, PhD -> 3 records
#   Pair hit: David E. Fisher, MD, PhD || Kimryn Rathmell, MD, PhD -> 2 records
#   Pair hit: David E. Fisher, MD, PhD || Nabeel Bardeesy, PhD -> 9 records
#   Pair hit: David E. Fisher, MD, PhD || Norman Sharpless, MD -> 6 records
#   Pair hit: David E. Fisher, MD, PhD || Scott Lowe, PhD -> 5 records
#   Pair hit: David Tuveson, MD, PhD || Edward Attiyeh, MD -> 2 records
#   Pair hit: David Tuveson, MD, PhD || Elsa Flores, PhD -> 2 records
#   Pair hit: David Tuveson, MD, PhD || James Amatruda, MD, PhD -> 5 records
#   Pair hit: David Tuveson, MD, PhD || Jan Karlseder, PhD -> 2 records
#   Pair hit: David Tuveson, MD, PhD || Kimryn Rathmell, MD, PhD -> 4 records
#   Pair hit: David Tuveson, MD, PhD || Masashi Narita, MD, PhD -> 2 records
#   Pair hit: David Tuveson, MD, PhD || Nabeel Bardeesy, PhD -> 11 records
#   Pair hit: David Tuveson, MD, PhD || Norman Sharpless, MD -> 8 records
#   Pair hit: David Tuveson, MD, PhD || Scott Lowe, PhD -> 7 records
#   Pair hit: Edward Attiyeh, MD || James Amatruda, MD, PhD -> 3 records
#   Pair hit: Edward Attiyeh, MD || Kimryn Rathmell, MD, PhD -> 2 records
#   Pair hit: Edward Attiyeh, MD || Nabeel Bardeesy, PhD -> 9 records
#   Pair hit: Edward Attiyeh, MD || Norman Sharpless, MD -> 6 records
#   Pair hit: Edward Attiyeh, MD || Scott Lowe, PhD -> 5 records
#   Pair hit: Elsa Flores, PhD || James Amatruda, MD, PhD -> 3 records
#   Pair hit: Elsa Flores, PhD || Kimryn Rathmell, MD, PhD -> 2 records
#   Pair hit: Elsa Flores, PhD || Nabeel Bardeesy, PhD -> 9 records
#   Pair hit: Elsa Flores, PhD || Norman Sharpless, MD -> 6 records
#   Pair hit: Elsa Flores, PhD || Scott Lowe, PhD -> 5 records
#   Pair hit: James Amatruda, MD, PhD || Jan Karlseder, PhD -> 3 records
#   Pair hit: James Amatruda, MD, PhD || Kimryn Rathmell, MD, PhD -> 5 records
#   Pair hit: James Amatruda, MD, PhD || Masashi Narita, MD, PhD -> 3 records
#   Pair hit: James Amatruda, MD, PhD || Nabeel Bardeesy, PhD -> 12 records
#   Pair hit: James Amatruda, MD, PhD || Norman Sharpless, MD -> 9 records
#   Pair hit: James Amatruda, MD, PhD || Scott Lowe, PhD -> 8 records
#   Pair hit: Jan Karlseder, PhD || Kimryn Rathmell, MD, PhD -> 2 records
#   Pair hit: Jan Karlseder, PhD || Nabeel Bardeesy, PhD -> 9 records
#   Pair hit: Jan Karlseder, PhD || Norman Sharpless, MD -> 6 records
#   Pair hit: Jan Karlseder, PhD || Scott Lowe, PhD -> 5 records
#   Pair hit: Kimryn Rathmell, MD, PhD || Masashi Narita, MD, PhD -> 2 records
#   Pair hit: Kimryn Rathmell, MD, PhD || Nabeel Bardeesy, PhD -> 11 records
#   Pair hit: Kimryn Rathmell, MD, PhD || Norman Sharpless, MD -> 8 records
#   Pair hit: Kimryn Rathmell, MD, PhD || Scott Lowe, PhD -> 7 records
#   Pair hit: Masashi Narita, MD, PhD || Nabeel Bardeesy, PhD -> 9 records
#   Pair hit: Masashi Narita, MD, PhD || Norman Sharpless, MD -> 6 records
#   Pair hit: Masashi Narita, MD, PhD || Scott Lowe, PhD -> 5 records
#   Pair hit: Nabeel Bardeesy, PhD || Norman Sharpless, MD -> 15 records
#   Pair hit: Nabeel Bardeesy, PhD || Scott Lowe, PhD -> 14 records
#   Pair hit: Norman Sharpless, MD || Scott Lowe, PhD -> 11 records
#
# BIN SUMMARY
#   Pairs with ≥1 result: 91
#   Unique appl_ids in bin: 1
#   Summed award amount (unique appl_id only): $0
#
# -----------------------------------------------
# Bin: 2015–2020
# Fiscal years: 2015..2020
#   Pair hit: Alison Bertuch, MD, PhD || Christopher Bakkenist, PhD -> 2 records
#   Pair hit: Alison Bertuch, MD, PhD || Craig Thompson, MD -> 6 records
#   Pair hit: Alison Bertuch, MD, PhD || David Tuveson, MD, PhD -> 7 records
#   Pair hit: Alison Bertuch, MD, PhD || Elsa Flores, PhD -> 2 records
#   Pair hit: Alison Bertuch, MD, PhD || James Amatruda, MD, PhD -> 2 records
#   Pair hit: Alison Bertuch, MD, PhD || Jan Karlseder, PhD -> 1 records
#   Pair hit: Alison Bertuch, MD, PhD || Kimryn Rathmell, MD, PhD -> 17 records
#   Pair hit: Alison Bertuch, MD, PhD || Nabeel Bardeesy, PhD -> 9 records
#   Pair hit: Alison Bertuch, MD, PhD || Norman Sharpless, MD -> 5 records
#   Pair hit: Alison Bertuch, MD, PhD || Scott Lowe, PhD -> 11 records
#   Pair hit: Anthony Letai, MD, PhD || Christopher Bakkenist, PhD -> 2 records
#   Pair hit: Anthony Letai, MD, PhD || Craig Thompson, MD -> 6 records
#   Pair hit: Anthony Letai, MD, PhD || David Tuveson, MD, PhD -> 7 records
#   Pair hit: Anthony Letai, MD, PhD || Elsa Flores, PhD -> 2 records
#   Pair hit: Anthony Letai, MD, PhD || James Amatruda, MD, PhD -> 2 records
#   Pair hit: Anthony Letai, MD, PhD || Jan Karlseder, PhD -> 1 records
#   Pair hit: Anthony Letai, MD, PhD || Kimryn Rathmell, MD, PhD -> 17 records
#   Pair hit: Anthony Letai, MD, PhD || Nabeel Bardeesy, PhD -> 9 records
#   Pair hit: Anthony Letai, MD, PhD || Norman Sharpless, MD -> 5 records
#   Pair hit: Anthony Letai, MD, PhD || Scott Lowe, PhD -> 11 records
#   Pair hit: Charles L. Sawyers, MD || Christopher Bakkenist, PhD -> 2 records
#   Pair hit: Charles L. Sawyers, MD || Craig Thompson, MD -> 6 records
#   Pair hit: Charles L. Sawyers, MD || David Tuveson, MD, PhD -> 7 records
#   Pair hit: Charles L. Sawyers, MD || Elsa Flores, PhD -> 2 records
#   Pair hit: Charles L. Sawyers, MD || James Amatruda, MD, PhD -> 2 records
#   Pair hit: Charles L. Sawyers, MD || Jan Karlseder, PhD -> 1 records
#   Pair hit: Charles L. Sawyers, MD || Kimryn Rathmell, MD, PhD -> 17 records
#   Pair hit: Charles L. Sawyers, MD || Nabeel Bardeesy, PhD -> 9 records
#   Pair hit: Charles L. Sawyers, MD || Norman Sharpless, MD -> 5 records
#   Pair hit: Charles L. Sawyers, MD || Scott Lowe, PhD -> 11 records
#   Pair hit: Charles Sherr, MD, PhD || Christopher Bakkenist, PhD -> 2 records
#   Pair hit: Charles Sherr, MD, PhD || Craig Thompson, MD -> 6 records
#   Pair hit: Charles Sherr, MD, PhD || David Tuveson, MD, PhD -> 7 records
#   Pair hit: Charles Sherr, MD, PhD || Elsa Flores, PhD -> 2 records
#   Pair hit: Charles Sherr, MD, PhD || James Amatruda, MD, PhD -> 2 records
#   Pair hit: Charles Sherr, MD, PhD || Jan Karlseder, PhD -> 1 records
#   Pair hit: Charles Sherr, MD, PhD || Kimryn Rathmell, MD, PhD -> 17 records
#   Pair hit: Charles Sherr, MD, PhD || Nabeel Bardeesy, PhD -> 9 records
#   Pair hit: Charles Sherr, MD, PhD || Norman Sharpless, MD -> 5 records
#   Pair hit: Charles Sherr, MD, PhD || Scott Lowe, PhD -> 11 records
#   Pair hit: Christopher Bakkenist, PhD || Craig Thompson, MD -> 8 records
#   Pair hit: Christopher Bakkenist, PhD || David E. Fisher, MD, PhD -> 2 records
#   Pair hit: Christopher Bakkenist, PhD || David Tuveson, MD, PhD -> 9 records
#   Pair hit: Christopher Bakkenist, PhD || Edward Attiyeh, MD -> 2 records
#   Pair hit: Christopher Bakkenist, PhD || Elsa Flores, PhD -> 4 records
#   Pair hit: Christopher Bakkenist, PhD || James Amatruda, MD, PhD -> 4 records
#   Pair hit: Christopher Bakkenist, PhD || Jan Karlseder, PhD -> 3 records
#   Pair hit: Christopher Bakkenist, PhD || Kimryn Rathmell, MD, PhD -> 19 records
#   Pair hit: Christopher Bakkenist, PhD || Masashi Narita, MD, PhD -> 2 records
#   Pair hit: Christopher Bakkenist, PhD || Nabeel Bardeesy, PhD -> 11 records
#   Pair hit: Christopher Bakkenist, PhD || Norman Sharpless, MD -> 7 records
#   Pair hit: Christopher Bakkenist, PhD || Scott Lowe, PhD -> 13 records
#   Pair hit: Craig Thompson, MD || David E. Fisher, MD, PhD -> 6 records
#   Pair hit: Craig Thompson, MD || David Tuveson, MD, PhD -> 13 records
#   Pair hit: Craig Thompson, MD || Edward Attiyeh, MD -> 6 records
#   Pair hit: Craig Thompson, MD || Elsa Flores, PhD -> 8 records
#   Pair hit: Craig Thompson, MD || James Amatruda, MD, PhD -> 8 records
#   Pair hit: Craig Thompson, MD || Jan Karlseder, PhD -> 7 records
#   Pair hit: Craig Thompson, MD || Kimryn Rathmell, MD, PhD -> 23 records
#   Pair hit: Craig Thompson, MD || Masashi Narita, MD, PhD -> 6 records
#   Pair hit: Craig Thompson, MD || Nabeel Bardeesy, PhD -> 15 records
#   Pair hit: Craig Thompson, MD || Norman Sharpless, MD -> 11 records
#   Pair hit: Craig Thompson, MD || Scott Lowe, PhD -> 17 records
#   Pair hit: David E. Fisher, MD, PhD || David Tuveson, MD, PhD -> 7 records
#   Pair hit: David E. Fisher, MD, PhD || Elsa Flores, PhD -> 2 records
#   Pair hit: David E. Fisher, MD, PhD || James Amatruda, MD, PhD -> 2 records
#   Pair hit: David E. Fisher, MD, PhD || Jan Karlseder, PhD -> 1 records
#   Pair hit: David E. Fisher, MD, PhD || Kimryn Rathmell, MD, PhD -> 17 records
#   Pair hit: David E. Fisher, MD, PhD || Nabeel Bardeesy, PhD -> 9 records
#   Pair hit: David E. Fisher, MD, PhD || Norman Sharpless, MD -> 5 records
#   Pair hit: David E. Fisher, MD, PhD || Scott Lowe, PhD -> 11 records
#   Pair hit: David Tuveson, MD, PhD || Edward Attiyeh, MD -> 7 records
#   Pair hit: David Tuveson, MD, PhD || Elsa Flores, PhD -> 9 records
#   Pair hit: David Tuveson, MD, PhD || James Amatruda, MD, PhD -> 9 records
#   Pair hit: David Tuveson, MD, PhD || Jan Karlseder, PhD -> 8 records
#   Pair hit: David Tuveson, MD, PhD || Kimryn Rathmell, MD, PhD -> 24 records
#   Pair hit: David Tuveson, MD, PhD || Masashi Narita, MD, PhD -> 7 records
#   Pair hit: David Tuveson, MD, PhD || Nabeel Bardeesy, PhD -> 16 records
#   Pair hit: David Tuveson, MD, PhD || Norman Sharpless, MD -> 12 records
#   Pair hit: David Tuveson, MD, PhD || Scott Lowe, PhD -> 18 records
#   Pair hit: Edward Attiyeh, MD || Elsa Flores, PhD -> 2 records
#   Pair hit: Edward Attiyeh, MD || James Amatruda, MD, PhD -> 2 records
#   Pair hit: Edward Attiyeh, MD || Jan Karlseder, PhD -> 1 records
#   Pair hit: Edward Attiyeh, MD || Kimryn Rathmell, MD, PhD -> 17 records
#   Pair hit: Edward Attiyeh, MD || Nabeel Bardeesy, PhD -> 9 records
#   Pair hit: Edward Attiyeh, MD || Norman Sharpless, MD -> 5 records
#   Pair hit: Edward Attiyeh, MD || Scott Lowe, PhD -> 11 records
#   Pair hit: Elsa Flores, PhD || James Amatruda, MD, PhD -> 4 records
#   Pair hit: Elsa Flores, PhD || Jan Karlseder, PhD -> 3 records
#   Pair hit: Elsa Flores, PhD || Kimryn Rathmell, MD, PhD -> 19 records
#   Pair hit: Elsa Flores, PhD || Masashi Narita, MD, PhD -> 2 records
#   Pair hit: Elsa Flores, PhD || Nabeel Bardeesy, PhD -> 11 records
#   Pair hit: Elsa Flores, PhD || Norman Sharpless, MD -> 7 records
#   Pair hit: Elsa Flores, PhD || Scott Lowe, PhD -> 13 records
#   Pair hit: James Amatruda, MD, PhD || Jan Karlseder, PhD -> 3 records
#   Pair hit: James Amatruda, MD, PhD || Kimryn Rathmell, MD, PhD -> 19 records
#   Pair hit: James Amatruda, MD, PhD || Masashi Narita, MD, PhD -> 2 records
#   Pair hit: James Amatruda, MD, PhD || Nabeel Bardeesy, PhD -> 11 records
#   Pair hit: James Amatruda, MD, PhD || Norman Sharpless, MD -> 7 records
#   Pair hit: James Amatruda, MD, PhD || Scott Lowe, PhD -> 13 records
#   Pair hit: Jan Karlseder, PhD || Kimryn Rathmell, MD, PhD -> 18 records
#   Pair hit: Jan Karlseder, PhD || Masashi Narita, MD, PhD -> 1 records
#   Pair hit: Jan Karlseder, PhD || Nabeel Bardeesy, PhD -> 10 records
#   Pair hit: Jan Karlseder, PhD || Norman Sharpless, MD -> 6 records
#   Pair hit: Jan Karlseder, PhD || Scott Lowe, PhD -> 12 records
#   Pair hit: Kimryn Rathmell, MD, PhD || Masashi Narita, MD, PhD -> 17 records
#   Pair hit: Kimryn Rathmell, MD, PhD || Nabeel Bardeesy, PhD -> 26 records
#   Pair hit: Kimryn Rathmell, MD, PhD || Norman Sharpless, MD -> 22 records
#   Pair hit: Kimryn Rathmell, MD, PhD || Scott Lowe, PhD -> 28 records
#   Pair hit: Masashi Narita, MD, PhD || Nabeel Bardeesy, PhD -> 9 records
#   Pair hit: Masashi Narita, MD, PhD || Norman Sharpless, MD -> 5 records
#   Pair hit: Masashi Narita, MD, PhD || Scott Lowe, PhD -> 11 records
#   Pair hit: Nabeel Bardeesy, PhD || Norman Sharpless, MD -> 14 records
#   Pair hit: Nabeel Bardeesy, PhD || Scott Lowe, PhD -> 20 records
#   Pair hit: Norman Sharpless, MD || Scott Lowe, PhD -> 16 records
#
# BIN SUMMARY
#   Pairs with ≥1 result: 115
#   Unique appl_ids in bin: 1
#   Summed award amount (unique appl_id only): $0
#
# ===================================================
# Meeting: 3D Chromosomal Architecture and Nuclear Topology (2019)
# Attendees in dict: 24
# Meeting year: 2019
# Parsable PI-like names: 24
# PI pairs to test: 276
#
# -----------------------------------------------
# Bin: 2014–2019
# Fiscal years: 2014..2019
#   Pair hit: Ari Melnick, MD || Benjamin Rowland, -> 13 records
#   Pair hit: Ari Melnick, MD || Bing Ren, PhD -> 43 records
#   Pair hit: Ari Melnick, MD || Brian Huntly, -> 13 records
#   Pair hit: Ari Melnick, MD || Clodagh O'Shea, PhD -> 19 records
#   Pair hit: Ari Melnick, MD || Danfeng Cai, PhD -> 13 records
#   Pair hit: Ari Melnick, MD || Denes Hnisz, -> 13 records
#   Pair hit: Ari Melnick, MD || Di Zhang, MD, PhD -> 35 records
#   Pair hit: Ari Melnick, MD || Eftychia Apostolou, PhD -> 13 records
#   Pair hit: Ari Melnick, MD || Elphege Nora, -> 13 records
#   Pair hit: Ari Melnick, MD || Francois Spitz, -> 13 records
#   Pair hit: Ari Melnick, MD || Gerd Blobel, MD, PhD -> 26 records
#   Pair hit: Ari Melnick, MD || Jan-Michael Peters, -> 13 records
#   Pair hit: Ari Melnick, MD || Jane Skok, PhD -> 17 records
#   Pair hit: Ari Melnick, MD || John Kemshead, -> 13 records
#   Pair hit: Ari Melnick, MD || Kathleen Xie, PhD -> 13 records
#   Pair hit: Ari Melnick, MD || Laura Banaszynski, PhD -> 13 records
#   Pair hit: Ari Melnick, MD || Leonid Mirny, PhD, M.Sc -> 20 records
#   Pair hit: Ari Melnick, MD || Martin Rivas, PhD -> 13 records
#   Pair hit: Ari Melnick, MD || Mathieu Lupien, PhD -> 13 records
#   Pair hit: Ari Melnick, MD || Peter Ly, PhD -> 76 records
#   Pair hit: Ari Melnick, MD || Peter Scacheri, PhD -> 24 records
#   Pair hit: Ari Melnick, MD || Ting Wang, PhD -> 26 records
#   Pair hit: Ari Melnick, MD || Tomi Pastinen, MD, PhD -> 13 records
#   Pair hit: Benjamin Rowland, || Bing Ren, PhD -> 30 records
#   Pair hit: Benjamin Rowland, || Clodagh O'Shea, PhD -> 6 records
#   Pair hit: Benjamin Rowland, || Di Zhang, MD, PhD -> 22 records
#   Pair hit: Benjamin Rowland, || Gerd Blobel, MD, PhD -> 13 records
#   Pair hit: Benjamin Rowland, || Jane Skok, PhD -> 4 records
#   Pair hit: Benjamin Rowland, || Leonid Mirny, PhD, M.Sc -> 7 records
#   Pair hit: Benjamin Rowland, || Peter Ly, PhD -> 63 records
#   Pair hit: Benjamin Rowland, || Peter Scacheri, PhD -> 11 records
#   Pair hit: Benjamin Rowland, || Ting Wang, PhD -> 13 records
#   Pair hit: Bing Ren, PhD || Brian Huntly, -> 30 records
#   Pair hit: Bing Ren, PhD || Clodagh O'Shea, PhD -> 36 records
#   Pair hit: Bing Ren, PhD || Danfeng Cai, PhD -> 30 records
#   Pair hit: Bing Ren, PhD || Denes Hnisz, -> 30 records
#   Pair hit: Bing Ren, PhD || Di Zhang, MD, PhD -> 52 records
#   Pair hit: Bing Ren, PhD || Eftychia Apostolou, PhD -> 30 records
#   Pair hit: Bing Ren, PhD || Elphege Nora, -> 30 records
#   Pair hit: Bing Ren, PhD || Francois Spitz, -> 30 records
#   Pair hit: Bing Ren, PhD || Gerd Blobel, MD, PhD -> 43 records
#   Pair hit: Bing Ren, PhD || Jan-Michael Peters, -> 30 records
#   Pair hit: Bing Ren, PhD || Jane Skok, PhD -> 34 records
#   Pair hit: Bing Ren, PhD || John Kemshead, -> 30 records
#   Pair hit: Bing Ren, PhD || Kathleen Xie, PhD -> 30 records
#   Pair hit: Bing Ren, PhD || Laura Banaszynski, PhD -> 30 records
#   Pair hit: Bing Ren, PhD || Leonid Mirny, PhD, M.Sc -> 37 records
#   Pair hit: Bing Ren, PhD || Martin Rivas, PhD -> 30 records
#   Pair hit: Bing Ren, PhD || Mathieu Lupien, PhD -> 30 records
#   Pair hit: Bing Ren, PhD || Peter Ly, PhD -> 93 records
#   Pair hit: Bing Ren, PhD || Peter Scacheri, PhD -> 41 records
#   Pair hit: Bing Ren, PhD || Ting Wang, PhD -> 43 records
#   Pair hit: Bing Ren, PhD || Tomi Pastinen, MD, PhD -> 30 records
#   Pair hit: Brian Huntly, || Clodagh O'Shea, PhD -> 6 records
#   Pair hit: Brian Huntly, || Di Zhang, MD, PhD -> 22 records
#   Pair hit: Brian Huntly, || Gerd Blobel, MD, PhD -> 13 records
#   Pair hit: Brian Huntly, || Jane Skok, PhD -> 4 records
#   Pair hit: Brian Huntly, || Leonid Mirny, PhD, M.Sc -> 7 records
#   Pair hit: Brian Huntly, || Peter Ly, PhD -> 63 records
#   Pair hit: Brian Huntly, || Peter Scacheri, PhD -> 11 records
#   Pair hit: Brian Huntly, || Ting Wang, PhD -> 13 records
#   Pair hit: Clodagh O'Shea, PhD || Danfeng Cai, PhD -> 6 records
#   Pair hit: Clodagh O'Shea, PhD || Denes Hnisz, -> 6 records
#   Pair hit: Clodagh O'Shea, PhD || Di Zhang, MD, PhD -> 28 records
#   Pair hit: Clodagh O'Shea, PhD || Eftychia Apostolou, PhD -> 6 records
#   Pair hit: Clodagh O'Shea, PhD || Elphege Nora, -> 6 records
#   Pair hit: Clodagh O'Shea, PhD || Francois Spitz, -> 6 records
#   Pair hit: Clodagh O'Shea, PhD || Gerd Blobel, MD, PhD -> 19 records
#   Pair hit: Clodagh O'Shea, PhD || Jan-Michael Peters, -> 6 records
#   Pair hit: Clodagh O'Shea, PhD || Jane Skok, PhD -> 10 records
#   Pair hit: Clodagh O'Shea, PhD || John Kemshead, -> 6 records
#   Pair hit: Clodagh O'Shea, PhD || Kathleen Xie, PhD -> 6 records
#   Pair hit: Clodagh O'Shea, PhD || Laura Banaszynski, PhD -> 6 records
#   Pair hit: Clodagh O'Shea, PhD || Leonid Mirny, PhD, M.Sc -> 13 records
#   Pair hit: Clodagh O'Shea, PhD || Martin Rivas, PhD -> 6 records
#   Pair hit: Clodagh O'Shea, PhD || Mathieu Lupien, PhD -> 6 records
#   Pair hit: Clodagh O'Shea, PhD || Peter Ly, PhD -> 69 records
#   Pair hit: Clodagh O'Shea, PhD || Peter Scacheri, PhD -> 17 records
#   Pair hit: Clodagh O'Shea, PhD || Ting Wang, PhD -> 19 records
#   Pair hit: Clodagh O'Shea, PhD || Tomi Pastinen, MD, PhD -> 6 records
#   Pair hit: Danfeng Cai, PhD || Di Zhang, MD, PhD -> 22 records
#   Pair hit: Danfeng Cai, PhD || Gerd Blobel, MD, PhD -> 13 records
#   Pair hit: Danfeng Cai, PhD || Jane Skok, PhD -> 4 records
#   Pair hit: Danfeng Cai, PhD || Leonid Mirny, PhD, M.Sc -> 7 records
#   Pair hit: Danfeng Cai, PhD || Peter Ly, PhD -> 63 records
#   Pair hit: Danfeng Cai, PhD || Peter Scacheri, PhD -> 11 records
#   Pair hit: Danfeng Cai, PhD || Ting Wang, PhD -> 13 records
#   Pair hit: Denes Hnisz, || Di Zhang, MD, PhD -> 22 records
#   Pair hit: Denes Hnisz, || Gerd Blobel, MD, PhD -> 13 records
#   Pair hit: Denes Hnisz, || Jane Skok, PhD -> 4 records
#   Pair hit: Denes Hnisz, || Leonid Mirny, PhD, M.Sc -> 7 records
#   Pair hit: Denes Hnisz, || Peter Ly, PhD -> 63 records
#   Pair hit: Denes Hnisz, || Peter Scacheri, PhD -> 11 records
#   Pair hit: Denes Hnisz, || Ting Wang, PhD -> 13 records
#   Pair hit: Di Zhang, MD, PhD || Eftychia Apostolou, PhD -> 22 records
#   Pair hit: Di Zhang, MD, PhD || Elphege Nora, -> 22 records
#   Pair hit: Di Zhang, MD, PhD || Francois Spitz, -> 22 records
#   Pair hit: Di Zhang, MD, PhD || Gerd Blobel, MD, PhD -> 31 records
#   Pair hit: Di Zhang, MD, PhD || Jan-Michael Peters, -> 22 records
#   Pair hit: Di Zhang, MD, PhD || Jane Skok, PhD -> 26 records
#   Pair hit: Di Zhang, MD, PhD || John Kemshead, -> 22 records
#   Pair hit: Di Zhang, MD, PhD || Kathleen Xie, PhD -> 22 records
#   Pair hit: Di Zhang, MD, PhD || Laura Banaszynski, PhD -> 22 records
#   Pair hit: Di Zhang, MD, PhD || Leonid Mirny, PhD, M.Sc -> 29 records
#   Pair hit: Di Zhang, MD, PhD || Martin Rivas, PhD -> 22 records
#   Pair hit: Di Zhang, MD, PhD || Mathieu Lupien, PhD -> 22 records
#   Pair hit: Di Zhang, MD, PhD || Peter Ly, PhD -> 85 records
#   Pair hit: Di Zhang, MD, PhD || Peter Scacheri, PhD -> 33 records
#   Pair hit: Di Zhang, MD, PhD || Ting Wang, PhD -> 35 records
#   Pair hit: Di Zhang, MD, PhD || Tomi Pastinen, MD, PhD -> 22 records
#   Pair hit: Eftychia Apostolou, PhD || Gerd Blobel, MD, PhD -> 13 records
#   Pair hit: Eftychia Apostolou, PhD || Jane Skok, PhD -> 4 records
#   Pair hit: Eftychia Apostolou, PhD || Leonid Mirny, PhD, M.Sc -> 7 records
#   Pair hit: Eftychia Apostolou, PhD || Peter Ly, PhD -> 63 records
#   Pair hit: Eftychia Apostolou, PhD || Peter Scacheri, PhD -> 11 records
#   Pair hit: Eftychia Apostolou, PhD || Ting Wang, PhD -> 13 records
#   Pair hit: Elphege Nora, || Gerd Blobel, MD, PhD -> 13 records
#   Pair hit: Elphege Nora, || Jane Skok, PhD -> 4 records
#   Pair hit: Elphege Nora, || Leonid Mirny, PhD, M.Sc -> 7 records
#   Pair hit: Elphege Nora, || Peter Ly, PhD -> 63 records
#   Pair hit: Elphege Nora, || Peter Scacheri, PhD -> 11 records
#   Pair hit: Elphege Nora, || Ting Wang, PhD -> 13 records
#   Pair hit: Francois Spitz, || Gerd Blobel, MD, PhD -> 13 records
#   Pair hit: Francois Spitz, || Jane Skok, PhD -> 4 records
#   Pair hit: Francois Spitz, || Leonid Mirny, PhD, M.Sc -> 7 records
#   Pair hit: Francois Spitz, || Peter Ly, PhD -> 63 records
#   Pair hit: Francois Spitz, || Peter Scacheri, PhD -> 11 records
#   Pair hit: Francois Spitz, || Ting Wang, PhD -> 13 records
#   Pair hit: Gerd Blobel, MD, PhD || Jan-Michael Peters, -> 13 records
#   Progress: tested 200/276 pairs; unique appl_ids so far: 1
#   Pair hit: Gerd Blobel, MD, PhD || Jane Skok, PhD -> 17 records
#   Pair hit: Gerd Blobel, MD, PhD || John Kemshead, -> 13 records
#   Pair hit: Gerd Blobel, MD, PhD || Kathleen Xie, PhD -> 13 records
#   Pair hit: Gerd Blobel, MD, PhD || Laura Banaszynski, PhD -> 13 records
#   Pair hit: Gerd Blobel, MD, PhD || Leonid Mirny, PhD, M.Sc -> 20 records
#   Pair hit: Gerd Blobel, MD, PhD || Martin Rivas, PhD -> 13 records
#   Pair hit: Gerd Blobel, MD, PhD || Mathieu Lupien, PhD -> 13 records
#   Pair hit: Gerd Blobel, MD, PhD || Peter Ly, PhD -> 76 records
#   Pair hit: Gerd Blobel, MD, PhD || Peter Scacheri, PhD -> 24 records
#   Pair hit: Gerd Blobel, MD, PhD || Ting Wang, PhD -> 26 records
#   Pair hit: Gerd Blobel, MD, PhD || Tomi Pastinen, MD, PhD -> 13 records
#   Pair hit: Jan-Michael Peters, || Jane Skok, PhD -> 4 records
#   Pair hit: Jan-Michael Peters, || Leonid Mirny, PhD, M.Sc -> 7 records
#   Pair hit: Jan-Michael Peters, || Peter Ly, PhD -> 63 records
#   Pair hit: Jan-Michael Peters, || Peter Scacheri, PhD -> 11 records
#   Pair hit: Jan-Michael Peters, || Ting Wang, PhD -> 13 records
#   Pair hit: Jane Skok, PhD || John Kemshead, -> 4 records
#   Pair hit: Jane Skok, PhD || Kathleen Xie, PhD -> 4 records
#   Pair hit: Jane Skok, PhD || Laura Banaszynski, PhD -> 4 records
#   Pair hit: Jane Skok, PhD || Leonid Mirny, PhD, M.Sc -> 11 records
#   Pair hit: Jane Skok, PhD || Martin Rivas, PhD -> 4 records
#   Pair hit: Jane Skok, PhD || Mathieu Lupien, PhD -> 4 records
#   Pair hit: Jane Skok, PhD || Peter Ly, PhD -> 67 records
#   Pair hit: Jane Skok, PhD || Peter Scacheri, PhD -> 15 records
#   Pair hit: Jane Skok, PhD || Ting Wang, PhD -> 17 records
#   Pair hit: Jane Skok, PhD || Tomi Pastinen, MD, PhD -> 4 records
#   Pair hit: John Kemshead, || Leonid Mirny, PhD, M.Sc -> 7 records
#   Pair hit: John Kemshead, || Peter Ly, PhD -> 63 records
#   Pair hit: John Kemshead, || Peter Scacheri, PhD -> 11 records
#   Pair hit: John Kemshead, || Ting Wang, PhD -> 13 records
#   Pair hit: Kathleen Xie, PhD || Leonid Mirny, PhD, M.Sc -> 7 records
#   Pair hit: Kathleen Xie, PhD || Peter Ly, PhD -> 63 records
#   Pair hit: Kathleen Xie, PhD || Peter Scacheri, PhD -> 11 records
#   Pair hit: Kathleen Xie, PhD || Ting Wang, PhD -> 13 records
#   Pair hit: Laura Banaszynski, PhD || Leonid Mirny, PhD, M.Sc -> 7 records
#   Pair hit: Laura Banaszynski, PhD || Peter Ly, PhD -> 63 records
#   Pair hit: Laura Banaszynski, PhD || Peter Scacheri, PhD -> 11 records
#   Pair hit: Laura Banaszynski, PhD || Ting Wang, PhD -> 13 records
#   Pair hit: Leonid Mirny, PhD, M.Sc || Martin Rivas, PhD -> 7 records
#   Pair hit: Leonid Mirny, PhD, M.Sc || Mathieu Lupien, PhD -> 7 records
#   Pair hit: Leonid Mirny, PhD, M.Sc || Peter Ly, PhD -> 70 records
#   Pair hit: Leonid Mirny, PhD, M.Sc || Peter Scacheri, PhD -> 18 records
#   Pair hit: Leonid Mirny, PhD, M.Sc || Ting Wang, PhD -> 20 records
#   Pair hit: Leonid Mirny, PhD, M.Sc || Tomi Pastinen, MD, PhD -> 7 records
#   Pair hit: Martin Rivas, PhD || Peter Ly, PhD -> 63 records
#   Pair hit: Martin Rivas, PhD || Peter Scacheri, PhD -> 11 records
#   Pair hit: Martin Rivas, PhD || Ting Wang, PhD -> 13 records
#   Pair hit: Mathieu Lupien, PhD || Peter Ly, PhD -> 63 records
#   Pair hit: Mathieu Lupien, PhD || Peter Scacheri, PhD -> 11 records
#   Pair hit: Mathieu Lupien, PhD || Ting Wang, PhD -> 13 records
#   Pair hit: Peter Ly, PhD || Peter Scacheri, PhD -> 74 records
#   Pair hit: Peter Ly, PhD || Ting Wang, PhD -> 76 records
#   Pair hit: Peter Ly, PhD || Tomi Pastinen, MD, PhD -> 63 records
#   Pair hit: Peter Scacheri, PhD || Ting Wang, PhD -> 24 records
#   Pair hit: Peter Scacheri, PhD || Tomi Pastinen, MD, PhD -> 11 records
#   Pair hit: Ting Wang, PhD || Tomi Pastinen, MD, PhD -> 13 records
#
# BIN SUMMARY
#   Pairs with ≥1 result: 185
#   Unique appl_ids in bin: 1
#   Summed award amount (unique appl_id only): $0
#
# -----------------------------------------------
# Bin: 2019–2024
# Fiscal years: 2019..2024
#   Pair hit: Ari Melnick, MD || Benjamin Rowland, -> 3 records
#   Pair hit: Ari Melnick, MD || Bing Ren, PhD -> 57 records
#   Pair hit: Ari Melnick, MD || Brian Huntly, -> 3 records
#   Pair hit: Ari Melnick, MD || Clodagh O'Shea, PhD -> 8 records
#   Pair hit: Ari Melnick, MD || Danfeng Cai, PhD -> 3 records
#   Pair hit: Ari Melnick, MD || Denes Hnisz, -> 3 records
#   Pair hit: Ari Melnick, MD || Di Zhang, MD, PhD -> 26 records
#   Pair hit: Ari Melnick, MD || Eftychia Apostolou, PhD -> 3 records
#   Pair hit: Ari Melnick, MD || Elphege Nora, -> 3 records
#   Pair hit: Ari Melnick, MD || Francois Spitz, -> 3 records
#   Pair hit: Ari Melnick, MD || Gerd Blobel, MD, PhD -> 13 records
#   Pair hit: Ari Melnick, MD || Jan-Michael Peters, -> 3 records
#   Pair hit: Ari Melnick, MD || Jane Skok, PhD -> 6 records
#   Pair hit: Ari Melnick, MD || John Kemshead, -> 3 records
#   Pair hit: Ari Melnick, MD || Kathleen Xie, PhD -> 3 records
#   Pair hit: Ari Melnick, MD || Laura Banaszynski, PhD -> 3 records
#   Pair hit: Ari Melnick, MD || Leonid Mirny, PhD, M.Sc -> 13 records
#   Pair hit: Ari Melnick, MD || Martin Rivas, PhD -> 3 records
#   Pair hit: Ari Melnick, MD || Mathieu Lupien, PhD -> 3 records
#   Pair hit: Ari Melnick, MD || Peter Ly, PhD -> 137 records
#   Pair hit: Ari Melnick, MD || Peter Scacheri, PhD -> 10 records
#   Pair hit: Ari Melnick, MD || Ting Wang, PhD -> 59 records
#   Pair hit: Ari Melnick, MD || Tomi Pastinen, MD, PhD -> 5 records
#   Pair hit: Benjamin Rowland, || Bing Ren, PhD -> 54 records
#   Pair hit: Benjamin Rowland, || Clodagh O'Shea, PhD -> 5 records
#   Pair hit: Benjamin Rowland, || Di Zhang, MD, PhD -> 23 records
#   Pair hit: Benjamin Rowland, || Gerd Blobel, MD, PhD -> 10 records
#   Pair hit: Benjamin Rowland, || Jane Skok, PhD -> 3 records
#   Pair hit: Benjamin Rowland, || Leonid Mirny, PhD, M.Sc -> 10 records
#   Pair hit: Benjamin Rowland, || Peter Ly, PhD -> 134 records
#   Pair hit: Benjamin Rowland, || Peter Scacheri, PhD -> 7 records
#   Pair hit: Benjamin Rowland, || Ting Wang, PhD -> 56 records
#   Pair hit: Benjamin Rowland, || Tomi Pastinen, MD, PhD -> 2 records
#   Pair hit: Bing Ren, PhD || Brian Huntly, -> 54 records
#   Pair hit: Bing Ren, PhD || Clodagh O'Shea, PhD -> 59 records
#   Pair hit: Bing Ren, PhD || Danfeng Cai, PhD -> 54 records
#   Pair hit: Bing Ren, PhD || Denes Hnisz, -> 54 records
#   Pair hit: Bing Ren, PhD || Di Zhang, MD, PhD -> 77 records
#   Pair hit: Bing Ren, PhD || Eftychia Apostolou, PhD -> 54 records
#   Pair hit: Bing Ren, PhD || Elphege Nora, -> 54 records
#   Pair hit: Bing Ren, PhD || Francois Spitz, -> 54 records
#   Pair hit: Bing Ren, PhD || Gerd Blobel, MD, PhD -> 64 records
#   Pair hit: Bing Ren, PhD || Jan-Michael Peters, -> 54 records
#   Pair hit: Bing Ren, PhD || Jane Skok, PhD -> 57 records
#   Pair hit: Bing Ren, PhD || John Kemshead, -> 54 records
#   Pair hit: Bing Ren, PhD || Kathleen Xie, PhD -> 54 records
#   Pair hit: Bing Ren, PhD || Laura Banaszynski, PhD -> 54 records
#   Pair hit: Bing Ren, PhD || Leonid Mirny, PhD, M.Sc -> 64 records
#   Pair hit: Bing Ren, PhD || Martin Rivas, PhD -> 54 records
#   Pair hit: Bing Ren, PhD || Mathieu Lupien, PhD -> 54 records
#   Pair hit: Bing Ren, PhD || Peter Ly, PhD -> 188 records
#   Pair hit: Bing Ren, PhD || Peter Scacheri, PhD -> 61 records
#   Pair hit: Bing Ren, PhD || Ting Wang, PhD -> 103 records
#   Pair hit: Bing Ren, PhD || Tomi Pastinen, MD, PhD -> 56 records
#   Pair hit: Brian Huntly, || Clodagh O'Shea, PhD -> 5 records
#   Pair hit: Brian Huntly, || Di Zhang, MD, PhD -> 23 records
#   Pair hit: Brian Huntly, || Gerd Blobel, MD, PhD -> 10 records
#   Pair hit: Brian Huntly, || Jane Skok, PhD -> 3 records
#   Pair hit: Brian Huntly, || Leonid Mirny, PhD, M.Sc -> 10 records
#   Pair hit: Brian Huntly, || Peter Ly, PhD -> 134 records
#   Pair hit: Brian Huntly, || Peter Scacheri, PhD -> 7 records
#   Pair hit: Brian Huntly, || Ting Wang, PhD -> 56 records
#   Pair hit: Brian Huntly, || Tomi Pastinen, MD, PhD -> 2 records
#   Pair hit: Clodagh O'Shea, PhD || Danfeng Cai, PhD -> 5 records
#   Pair hit: Clodagh O'Shea, PhD || Denes Hnisz, -> 5 records
#   Pair hit: Clodagh O'Shea, PhD || Di Zhang, MD, PhD -> 28 records
#   Pair hit: Clodagh O'Shea, PhD || Eftychia Apostolou, PhD -> 5 records
#   Pair hit: Clodagh O'Shea, PhD || Elphege Nora, -> 5 records
#   Pair hit: Clodagh O'Shea, PhD || Francois Spitz, -> 5 records
#   Pair hit: Clodagh O'Shea, PhD || Gerd Blobel, MD, PhD -> 15 records
#   Pair hit: Clodagh O'Shea, PhD || Jan-Michael Peters, -> 5 records
#   Pair hit: Clodagh O'Shea, PhD || Jane Skok, PhD -> 8 records
#   Pair hit: Clodagh O'Shea, PhD || John Kemshead, -> 5 records
#   Pair hit: Clodagh O'Shea, PhD || Kathleen Xie, PhD -> 5 records
#   Pair hit: Clodagh O'Shea, PhD || Laura Banaszynski, PhD -> 5 records
#   Pair hit: Clodagh O'Shea, PhD || Leonid Mirny, PhD, M.Sc -> 15 records
#   Pair hit: Clodagh O'Shea, PhD || Martin Rivas, PhD -> 5 records
#   Pair hit: Clodagh O'Shea, PhD || Mathieu Lupien, PhD -> 5 records
#   Pair hit: Clodagh O'Shea, PhD || Peter Ly, PhD -> 139 records
#   Pair hit: Clodagh O'Shea, PhD || Peter Scacheri, PhD -> 12 records
#   Pair hit: Clodagh O'Shea, PhD || Ting Wang, PhD -> 61 records
#   Pair hit: Clodagh O'Shea, PhD || Tomi Pastinen, MD, PhD -> 7 records
#   Pair hit: Danfeng Cai, PhD || Di Zhang, MD, PhD -> 23 records
#   Pair hit: Danfeng Cai, PhD || Gerd Blobel, MD, PhD -> 10 records
#   Pair hit: Danfeng Cai, PhD || Jane Skok, PhD -> 3 records
#   Pair hit: Danfeng Cai, PhD || Leonid Mirny, PhD, M.Sc -> 10 records
#   Pair hit: Danfeng Cai, PhD || Peter Ly, PhD -> 134 records
#   Pair hit: Danfeng Cai, PhD || Peter Scacheri, PhD -> 7 records
#   Pair hit: Danfeng Cai, PhD || Ting Wang, PhD -> 56 records
#   Pair hit: Danfeng Cai, PhD || Tomi Pastinen, MD, PhD -> 2 records
#   Pair hit: Denes Hnisz, || Di Zhang, MD, PhD -> 23 records
#   Pair hit: Denes Hnisz, || Gerd Blobel, MD, PhD -> 10 records
#   Pair hit: Denes Hnisz, || Jane Skok, PhD -> 3 records
#   Pair hit: Denes Hnisz, || Leonid Mirny, PhD, M.Sc -> 10 records
#   Pair hit: Denes Hnisz, || Peter Ly, PhD -> 134 records
#   Pair hit: Denes Hnisz, || Peter Scacheri, PhD -> 7 records
#   Pair hit: Denes Hnisz, || Ting Wang, PhD -> 56 records
#   Pair hit: Denes Hnisz, || Tomi Pastinen, MD, PhD -> 2 records
#   Pair hit: Di Zhang, MD, PhD || Eftychia Apostolou, PhD -> 23 records
#   Pair hit: Di Zhang, MD, PhD || Elphege Nora, -> 23 records
#   Pair hit: Di Zhang, MD, PhD || Francois Spitz, -> 23 records
#   Pair hit: Di Zhang, MD, PhD || Gerd Blobel, MD, PhD -> 31 records
#   Pair hit: Di Zhang, MD, PhD || Jan-Michael Peters, -> 23 records
#   Pair hit: Di Zhang, MD, PhD || Jane Skok, PhD -> 26 records
#   Pair hit: Di Zhang, MD, PhD || John Kemshead, -> 23 records
#   Pair hit: Di Zhang, MD, PhD || Kathleen Xie, PhD -> 23 records
#   Pair hit: Di Zhang, MD, PhD || Laura Banaszynski, PhD -> 23 records
#   Pair hit: Di Zhang, MD, PhD || Leonid Mirny, PhD, M.Sc -> 33 records
#   Pair hit: Di Zhang, MD, PhD || Martin Rivas, PhD -> 23 records
#   Pair hit: Di Zhang, MD, PhD || Mathieu Lupien, PhD -> 23 records
#   Pair hit: Di Zhang, MD, PhD || Peter Ly, PhD -> 157 records
#   Pair hit: Di Zhang, MD, PhD || Peter Scacheri, PhD -> 30 records
#   Pair hit: Di Zhang, MD, PhD || Ting Wang, PhD -> 79 records
#   Pair hit: Di Zhang, MD, PhD || Tomi Pastinen, MD, PhD -> 25 records
#   Pair hit: Eftychia Apostolou, PhD || Gerd Blobel, MD, PhD -> 10 records
#   Pair hit: Eftychia Apostolou, PhD || Jane Skok, PhD -> 3 records
#   Pair hit: Eftychia Apostolou, PhD || Leonid Mirny, PhD, M.Sc -> 10 records
#   Pair hit: Eftychia Apostolou, PhD || Peter Ly, PhD -> 134 records
#   Pair hit: Eftychia Apostolou, PhD || Peter Scacheri, PhD -> 7 records
#   Pair hit: Eftychia Apostolou, PhD || Ting Wang, PhD -> 56 records
#   Pair hit: Eftychia Apostolou, PhD || Tomi Pastinen, MD, PhD -> 2 records
#   Pair hit: Elphege Nora, || Gerd Blobel, MD, PhD -> 10 records
#   Pair hit: Elphege Nora, || Jane Skok, PhD -> 3 records
#   Pair hit: Elphege Nora, || Leonid Mirny, PhD, M.Sc -> 10 records
#   Pair hit: Elphege Nora, || Peter Ly, PhD -> 134 records
#   Pair hit: Elphege Nora, || Peter Scacheri, PhD -> 7 records
#   Pair hit: Elphege Nora, || Ting Wang, PhD -> 56 records
#   Pair hit: Elphege Nora, || Tomi Pastinen, MD, PhD -> 2 records
#   Pair hit: Francois Spitz, || Gerd Blobel, MD, PhD -> 10 records
#   Pair hit: Francois Spitz, || Jane Skok, PhD -> 3 records
#   Pair hit: Francois Spitz, || Leonid Mirny, PhD, M.Sc -> 10 records
#   Pair hit: Francois Spitz, || Peter Ly, PhD -> 134 records
#   Pair hit: Francois Spitz, || Peter Scacheri, PhD -> 7 records
#   Pair hit: Francois Spitz, || Ting Wang, PhD -> 56 records
#   Pair hit: Francois Spitz, || Tomi Pastinen, MD, PhD -> 2 records
#   Pair hit: Gerd Blobel, MD, PhD || Jan-Michael Peters, -> 10 records
#   Progress: tested 200/276 pairs; unique appl_ids so far: 1
#   Pair hit: Gerd Blobel, MD, PhD || Jane Skok, PhD -> 13 records
#   Pair hit: Gerd Blobel, MD, PhD || John Kemshead, -> 10 records
#   Pair hit: Gerd Blobel, MD, PhD || Kathleen Xie, PhD -> 10 records
#   Pair hit: Gerd Blobel, MD, PhD || Laura Banaszynski, PhD -> 10 records
#   Pair hit: Gerd Blobel, MD, PhD || Leonid Mirny, PhD, M.Sc -> 20 records
#   Pair hit: Gerd Blobel, MD, PhD || Martin Rivas, PhD -> 10 records
#   Pair hit: Gerd Blobel, MD, PhD || Mathieu Lupien, PhD -> 10 records
#   Pair hit: Gerd Blobel, MD, PhD || Peter Ly, PhD -> 144 records
#   Pair hit: Gerd Blobel, MD, PhD || Peter Scacheri, PhD -> 17 records
#   Pair hit: Gerd Blobel, MD, PhD || Ting Wang, PhD -> 66 records
#   Pair hit: Gerd Blobel, MD, PhD || Tomi Pastinen, MD, PhD -> 12 records
#   Pair hit: Jan-Michael Peters, || Jane Skok, PhD -> 3 records
#   Pair hit: Jan-Michael Peters, || Leonid Mirny, PhD, M.Sc -> 10 records
#   Pair hit: Jan-Michael Peters, || Peter Ly, PhD -> 134 records
#   Pair hit: Jan-Michael Peters, || Peter Scacheri, PhD -> 7 records
#   Pair hit: Jan-Michael Peters, || Ting Wang, PhD -> 56 records
#   Pair hit: Jan-Michael Peters, || Tomi Pastinen, MD, PhD -> 2 records
#   Pair hit: Jane Skok, PhD || John Kemshead, -> 3 records
#   Pair hit: Jane Skok, PhD || Kathleen Xie, PhD -> 3 records
#   Pair hit: Jane Skok, PhD || Laura Banaszynski, PhD -> 3 records
#   Pair hit: Jane Skok, PhD || Leonid Mirny, PhD, M.Sc -> 13 records
#   Pair hit: Jane Skok, PhD || Martin Rivas, PhD -> 3 records
#   Pair hit: Jane Skok, PhD || Mathieu Lupien, PhD -> 3 records
#   Pair hit: Jane Skok, PhD || Peter Ly, PhD -> 137 records
#   Pair hit: Jane Skok, PhD || Peter Scacheri, PhD -> 10 records
#   Pair hit: Jane Skok, PhD || Ting Wang, PhD -> 59 records
#   Pair hit: Jane Skok, PhD || Tomi Pastinen, MD, PhD -> 5 records
#   Pair hit: John Kemshead, || Leonid Mirny, PhD, M.Sc -> 10 records
#   Pair hit: John Kemshead, || Peter Ly, PhD -> 134 records
#   Pair hit: John Kemshead, || Peter Scacheri, PhD -> 7 records
#   Pair hit: John Kemshead, || Ting Wang, PhD -> 56 records
#   Pair hit: John Kemshead, || Tomi Pastinen, MD, PhD -> 2 records
#   Pair hit: Kathleen Xie, PhD || Leonid Mirny, PhD, M.Sc -> 10 records
#   Pair hit: Kathleen Xie, PhD || Peter Ly, PhD -> 134 records
#   Pair hit: Kathleen Xie, PhD || Peter Scacheri, PhD -> 7 records
#   Pair hit: Kathleen Xie, PhD || Ting Wang, PhD -> 56 records
#   Pair hit: Kathleen Xie, PhD || Tomi Pastinen, MD, PhD -> 2 records
#   Pair hit: Laura Banaszynski, PhD || Leonid Mirny, PhD, M.Sc -> 10 records
#   Pair hit: Laura Banaszynski, PhD || Peter Ly, PhD -> 134 records
#   Pair hit: Laura Banaszynski, PhD || Peter Scacheri, PhD -> 7 records
#   Pair hit: Laura Banaszynski, PhD || Ting Wang, PhD -> 56 records
#   Pair hit: Laura Banaszynski, PhD || Tomi Pastinen, MD, PhD -> 2 records
#   Pair hit: Leonid Mirny, PhD, M.Sc || Martin Rivas, PhD -> 10 records
#   Pair hit: Leonid Mirny, PhD, M.Sc || Mathieu Lupien, PhD -> 10 records
#   Pair hit: Leonid Mirny, PhD, M.Sc || Peter Ly, PhD -> 144 records
#   Pair hit: Leonid Mirny, PhD, M.Sc || Peter Scacheri, PhD -> 17 records
#   Pair hit: Leonid Mirny, PhD, M.Sc || Ting Wang, PhD -> 66 records
#   Pair hit: Leonid Mirny, PhD, M.Sc || Tomi Pastinen, MD, PhD -> 12 records
#   Pair hit: Martin Rivas, PhD || Peter Ly, PhD -> 134 records
#   Pair hit: Martin Rivas, PhD || Peter Scacheri, PhD -> 7 records
#   Pair hit: Martin Rivas, PhD || Ting Wang, PhD -> 56 records
#   Pair hit: Martin Rivas, PhD || Tomi Pastinen, MD, PhD -> 2 records
#   Pair hit: Mathieu Lupien, PhD || Peter Ly, PhD -> 134 records
#   Pair hit: Mathieu Lupien, PhD || Peter Scacheri, PhD -> 7 records
#   Pair hit: Mathieu Lupien, PhD || Ting Wang, PhD -> 56 records
#   Pair hit: Mathieu Lupien, PhD || Tomi Pastinen, MD, PhD -> 2 records
#   Pair hit: Peter Ly, PhD || Peter Scacheri, PhD -> 141 records
#   Pair hit: Peter Ly, PhD || Ting Wang, PhD -> 190 records
#   Pair hit: Peter Ly, PhD || Tomi Pastinen, MD, PhD -> 136 records
#   Pair hit: Peter Scacheri, PhD || Ting Wang, PhD -> 63 records
#   Pair hit: Peter Scacheri, PhD || Tomi Pastinen, MD, PhD -> 9 records
#   Pair hit: Ting Wang, PhD || Tomi Pastinen, MD, PhD -> 58 records
#
# BIN SUMMARY
#   Pairs with ≥1 result: 198
#   Unique appl_ids in bin: 1
#   Summed award amount (unique appl_id only): $0
#
# -----------------------------------------------
# Bin: 2024–2029
# Fiscal years: 2024..2029
#   Pair hit: Ari Melnick, MD || Bing Ren, PhD -> 17 records
#   Pair hit: Ari Melnick, MD || Clodagh O'Shea, PhD -> 2 records
#   Pair hit: Ari Melnick, MD || Di Zhang, MD, PhD -> 12 records
#   Pair hit: Ari Melnick, MD || Gerd Blobel, MD, PhD -> 2 records
#   Pair hit: Ari Melnick, MD || Jane Skok, PhD -> 2 records
#   Pair hit: Ari Melnick, MD || Leonid Mirny, PhD, M.Sc -> 1 records
#   Pair hit: Ari Melnick, MD || Peter Ly, PhD -> 37 records
#   Pair hit: Ari Melnick, MD || Ting Wang, PhD -> 25 records
#   Pair hit: Ari Melnick, MD || Tomi Pastinen, MD, PhD -> 7 records
#   Pair hit: Benjamin Rowland, || Bing Ren, PhD -> 17 records
#   Pair hit: Benjamin Rowland, || Clodagh O'Shea, PhD -> 2 records
#   Pair hit: Benjamin Rowland, || Di Zhang, MD, PhD -> 12 records
#   Pair hit: Benjamin Rowland, || Gerd Blobel, MD, PhD -> 2 records
#   Pair hit: Benjamin Rowland, || Jane Skok, PhD -> 2 records
#   Pair hit: Benjamin Rowland, || Leonid Mirny, PhD, M.Sc -> 1 records
#   Pair hit: Benjamin Rowland, || Peter Ly, PhD -> 37 records
#   Pair hit: Benjamin Rowland, || Ting Wang, PhD -> 25 records
#   Pair hit: Benjamin Rowland, || Tomi Pastinen, MD, PhD -> 7 records
#   Pair hit: Bing Ren, PhD || Brian Huntly, -> 17 records
#   Pair hit: Bing Ren, PhD || Clodagh O'Shea, PhD -> 19 records
#   Pair hit: Bing Ren, PhD || Danfeng Cai, PhD -> 17 records
#   Pair hit: Bing Ren, PhD || Denes Hnisz, -> 17 records
#   Pair hit: Bing Ren, PhD || Di Zhang, MD, PhD -> 29 records
#   Pair hit: Bing Ren, PhD || Eftychia Apostolou, PhD -> 17 records
#   Pair hit: Bing Ren, PhD || Elphege Nora, -> 17 records
#   Pair hit: Bing Ren, PhD || Francois Spitz, -> 17 records
#   Pair hit: Bing Ren, PhD || Gerd Blobel, MD, PhD -> 19 records
#   Pair hit: Bing Ren, PhD || Jan-Michael Peters, -> 17 records
#   Pair hit: Bing Ren, PhD || Jane Skok, PhD -> 19 records
#   Pair hit: Bing Ren, PhD || John Kemshead, -> 17 records
#   Pair hit: Bing Ren, PhD || Kathleen Xie, PhD -> 17 records
#   Pair hit: Bing Ren, PhD || Laura Banaszynski, PhD -> 17 records
#   Pair hit: Bing Ren, PhD || Leonid Mirny, PhD, M.Sc -> 18 records
#   Pair hit: Bing Ren, PhD || Martin Rivas, PhD -> 17 records
#   Pair hit: Bing Ren, PhD || Mathieu Lupien, PhD -> 17 records
#   Pair hit: Bing Ren, PhD || Peter Ly, PhD -> 54 records
#   Pair hit: Bing Ren, PhD || Peter Scacheri, PhD -> 17 records
#   Pair hit: Bing Ren, PhD || Ting Wang, PhD -> 40 records
#   Pair hit: Bing Ren, PhD || Tomi Pastinen, MD, PhD -> 24 records
#   Pair hit: Brian Huntly, || Clodagh O'Shea, PhD -> 2 records
#   Pair hit: Brian Huntly, || Di Zhang, MD, PhD -> 12 records
#   Pair hit: Brian Huntly, || Gerd Blobel, MD, PhD -> 2 records
#   Pair hit: Brian Huntly, || Jane Skok, PhD -> 2 records
#   Pair hit: Brian Huntly, || Leonid Mirny, PhD, M.Sc -> 1 records
#   Pair hit: Brian Huntly, || Peter Ly, PhD -> 37 records
#   Pair hit: Brian Huntly, || Ting Wang, PhD -> 25 records
#   Pair hit: Brian Huntly, || Tomi Pastinen, MD, PhD -> 7 records
#   Pair hit: Clodagh O'Shea, PhD || Danfeng Cai, PhD -> 2 records
#   Pair hit: Clodagh O'Shea, PhD || Denes Hnisz, -> 2 records
#   Pair hit: Clodagh O'Shea, PhD || Di Zhang, MD, PhD -> 14 records
#   Pair hit: Clodagh O'Shea, PhD || Eftychia Apostolou, PhD -> 2 records
#   Pair hit: Clodagh O'Shea, PhD || Elphege Nora, -> 2 records
#   Pair hit: Clodagh O'Shea, PhD || Francois Spitz, -> 2 records
#   Pair hit: Clodagh O'Shea, PhD || Gerd Blobel, MD, PhD -> 4 records
#   Pair hit: Clodagh O'Shea, PhD || Jan-Michael Peters, -> 2 records
#   Pair hit: Clodagh O'Shea, PhD || Jane Skok, PhD -> 4 records
#   Pair hit: Clodagh O'Shea, PhD || John Kemshead, -> 2 records
#   Pair hit: Clodagh O'Shea, PhD || Kathleen Xie, PhD -> 2 records
#   Pair hit: Clodagh O'Shea, PhD || Laura Banaszynski, PhD -> 2 records
#   Pair hit: Clodagh O'Shea, PhD || Leonid Mirny, PhD, M.Sc -> 3 records
#   Pair hit: Clodagh O'Shea, PhD || Martin Rivas, PhD -> 2 records
#   Pair hit: Clodagh O'Shea, PhD || Mathieu Lupien, PhD -> 2 records
#   Pair hit: Clodagh O'Shea, PhD || Peter Ly, PhD -> 39 records
#   Pair hit: Clodagh O'Shea, PhD || Peter Scacheri, PhD -> 2 records
#   Pair hit: Clodagh O'Shea, PhD || Ting Wang, PhD -> 27 records
#   Pair hit: Clodagh O'Shea, PhD || Tomi Pastinen, MD, PhD -> 9 records
#   Pair hit: Danfeng Cai, PhD || Di Zhang, MD, PhD -> 12 records
#   Pair hit: Danfeng Cai, PhD || Gerd Blobel, MD, PhD -> 2 records
# ...
#   Pair hit: Gerd Blobel, MD, PhD || Kathleen Xie, PhD -> 2 records
#   Pair hit: Gerd Blobel, MD, PhD || Laura Banaszynski, PhD -> 2 records
#   Pair hit: Gerd Blobel, MD, PhD || Leonid Mirny, PhD, M.Sc -> 3 records
#   Pair hit: Gerd Blobel, MD, PhD || Martin Rivas, PhD -> 2 records
#   Pair hit: Gerd Blobel, MD, PhD || Mathieu Lupien, PhD -> 2 records
#   Pair hit: Gerd Blobel, MD, PhD || Peter Ly, PhD -> 39 records
#   Pair hit: Gerd Blobel, MD, PhD || Peter Scacheri, PhD -> 2 records
#   Pair hit: Gerd Blobel, MD, PhD || Ting Wang, PhD -> 27 records
#   Pair hit: Gerd Blobel, MD, PhD || Tomi Pastinen, MD, PhD -> 9 records
#   Pair hit: Jan-Michael Peters, || Jane Skok, PhD -> 2 records
#   Pair hit: Jan-Michael Peters, || Leonid Mirny, PhD, M.Sc -> 1 records
#   Pair hit: Jan-Michael Peters, || Peter Ly, PhD -> 37 records
#   Pair hit: Jan-Michael Peters, || Ting Wang, PhD -> 25 records
#   Pair hit: Jan-Michael Peters, || Tomi Pastinen, MD, PhD -> 7 records
#   Pair hit: Jane Skok, PhD || John Kemshead, -> 2 records
#   Pair hit: Jane Skok, PhD || Kathleen Xie, PhD -> 2 records
#   Pair hit: Jane Skok, PhD || Laura Banaszynski, PhD -> 2 records
#   Pair hit: Jane Skok, PhD || Leonid Mirny, PhD, M.Sc -> 3 records
#   Pair hit: Jane Skok, PhD || Martin Rivas, PhD -> 2 records
#   Pair hit: Jane Skok, PhD || Mathieu Lupien, PhD -> 2 records
#   Pair hit: Jane Skok, PhD || Peter Ly, PhD -> 39 records
#   Pair hit: Jane Skok, PhD || Peter Scacheri, PhD -> 2 records
#   Pair hit: Jane Skok, PhD || Ting Wang, PhD -> 27 records
#   Pair hit: Jane Skok, PhD || Tomi Pastinen, MD, PhD -> 9 records
#   Pair hit: John Kemshead, || Leonid Mirny, PhD, M.Sc -> 1 records
#   Pair hit: John Kemshead, || Peter Ly, PhD -> 37 records
#   Pair hit: John Kemshead, || Ting Wang, PhD -> 25 records
#   Pair hit: John Kemshead, || Tomi Pastinen, MD, PhD -> 7 records
#   Pair hit: Kathleen Xie, PhD || Leonid Mirny, PhD, M.Sc -> 1 records
#   Pair hit: Kathleen Xie, PhD || Peter Ly, PhD -> 37 records
#   Pair hit: Kathleen Xie, PhD || Ting Wang, PhD -> 25 records
#   Pair hit: Kathleen Xie, PhD || Tomi Pastinen, MD, PhD -> 7 records
#   Pair hit: Laura Banaszynski, PhD || Leonid Mirny, PhD, M.Sc -> 1 records
#   Pair hit: Laura Banaszynski, PhD || Peter Ly, PhD -> 37 records
#   Pair hit: Laura Banaszynski, PhD || Ting Wang, PhD -> 25 records
#   Pair hit: Laura Banaszynski, PhD || Tomi Pastinen, MD, PhD -> 7 records
#   Pair hit: Leonid Mirny, PhD, M.Sc || Martin Rivas, PhD -> 1 records
#   Pair hit: Leonid Mirny, PhD, M.Sc || Mathieu Lupien, PhD -> 1 records
#   Pair hit: Leonid Mirny, PhD, M.Sc || Peter Ly, PhD -> 38 records
#   Pair hit: Leonid Mirny, PhD, M.Sc || Peter Scacheri, PhD -> 1 records
#   Pair hit: Leonid Mirny, PhD, M.Sc || Ting Wang, PhD -> 26 records
#   Pair hit: Leonid Mirny, PhD, M.Sc || Tomi Pastinen, MD, PhD -> 8 records
#   Pair hit: Martin Rivas, PhD || Peter Ly, PhD -> 37 records
#   Pair hit: Martin Rivas, PhD || Ting Wang, PhD -> 25 records
#   Pair hit: Martin Rivas, PhD || Tomi Pastinen, MD, PhD -> 7 records
#   Pair hit: Mathieu Lupien, PhD || Peter Ly, PhD -> 37 records
#   Pair hit: Mathieu Lupien, PhD || Ting Wang, PhD -> 25 records
#   Pair hit: Mathieu Lupien, PhD || Tomi Pastinen, MD, PhD -> 7 records
#   Pair hit: Peter Ly, PhD || Peter Scacheri, PhD -> 37 records
#   Pair hit: Peter Ly, PhD || Ting Wang, PhD -> 62 records
#   Pair hit: Peter Ly, PhD || Tomi Pastinen, MD, PhD -> 44 records
#   Pair hit: Peter Scacheri, PhD || Ting Wang, PhD -> 25 records
#   Pair hit: Peter Scacheri, PhD || Tomi Pastinen, MD, PhD -> 7 records
#   Pair hit: Ting Wang, PhD || Tomi Pastinen, MD, PhD -> 32 records
#
# BIN SUMMARY
#   Pairs with ≥1 result: 171
#   Unique appl_ids in bin: 1
#   Summed award amount (unique appl_id only): $0
#
# -----------------------------------------------
# Bin: 2029–2034
# Fiscal years: 2029..2034
#   Progress: tested 200/276 pairs; unique appl_ids so far: 0
#
# BIN SUMMARY
#   Pairs with ≥1 result: 0
#   Unique appl_ids in bin: 0
#   Summed award amount (unique appl_id only): $0
#
# ===================================================
# Meeting: Targeting Lipid Biology in Cancer (2023)
# Attendees in dict: 18
# Meeting year: 2023
# Parsable PI-like names: 18
# PI pairs to test: 153
#
# -----------------------------------------------
# Bin: 2018–2023
# Fiscal years: 2018..2023
#   Pair hit: Alison Ringel, PhD || David Fruman, PhD -> 3 records
#   Pair hit: Alison Ringel, PhD || Jeremy Baskin, PhD -> 3 records
#   Pair hit: Alison Ringel, PhD || Livia  Schiavinato Eberlin, PhD -> 5 records
#   Pair hit: Alison Ringel, PhD || Neil Vasan, MD, PhD -> 4 records
#   Pair hit: Bart Vanhaesebroeck, PhD || David Fruman, PhD -> 3 records
#   Pair hit: Bart Vanhaesebroeck, PhD || Jeremy Baskin, PhD -> 3 records
#   Pair hit: Bart Vanhaesebroeck, PhD || Livia  Schiavinato Eberlin, PhD -> 5 records
#   Pair hit: Bart Vanhaesebroeck, PhD || Neil Vasan, MD, PhD -> 4 records
#   Pair hit: Brooke Emerling, PhD || David Fruman, PhD -> 3 records
#   Pair hit: Brooke Emerling, PhD || Jeremy Baskin, PhD -> 3 records
#   Pair hit: Brooke Emerling, PhD || Livia  Schiavinato Eberlin, PhD -> 5 records
#   Pair hit: Brooke Emerling, PhD || Neil Vasan, MD, PhD -> 4 records
#   Pair hit: Christina Mitchell, MB BS, PhD || David Fruman, PhD -> 3 records
#   Pair hit: Christina Mitchell, MB BS, PhD || Jeremy Baskin, PhD -> 3 records
#   Pair hit: Christina Mitchell, MB BS, PhD || Livia  Schiavinato Eberlin, PhD -> 5 records
#   Pair hit: Christina Mitchell, MB BS, PhD || Neil Vasan, MD, PhD -> 4 records
#   Pair hit: David Fruman, PhD || Emilio Hirsch, PhD -> 3 records
#   Pair hit: David Fruman, PhD || Gretchen Alicea, PhD -> 3 records
#   Pair hit: David Fruman, PhD || Hua Eleanor Yu, PhD -> 3 records
#   Pair hit: David Fruman, PhD || Jeremy Baskin, PhD -> 6 records
#   Pair hit: David Fruman, PhD || Karen Dixon, -> 3 records
#   Pair hit: David Fruman, PhD || Livia  Schiavinato Eberlin, PhD -> 8 records
#   Pair hit: David Fruman, PhD || Neil Vasan, MD, PhD -> 7 records
#   Pair hit: David Fruman, PhD || Prof Banafshe  Larijani , PhD -> 3 records
#   Pair hit: David Fruman, PhD || Ray Blind, -> 3 records
#   Pair hit: David Fruman, PhD || Sarah  Skuli, -> 3 records
#   Pair hit: David Fruman, PhD || Tamas Balla, MD, PhD -> 3 records
#   Pair hit: David Fruman, PhD || Targeting Lipid Biology in Cancer -> 3 records
#   Pair hit: David Fruman, PhD || Vytas Bankaitis, PhD -> 3 records
#   Pair hit: Emilio Hirsch, PhD || Jeremy Baskin, PhD -> 3 records
#   Pair hit: Emilio Hirsch, PhD || Livia  Schiavinato Eberlin, PhD -> 5 records
#   Pair hit: Emilio Hirsch, PhD || Neil Vasan, MD, PhD -> 4 records
#   Pair hit: Gretchen Alicea, PhD || Jeremy Baskin, PhD -> 3 records
#   Pair hit: Gretchen Alicea, PhD || Livia  Schiavinato Eberlin, PhD -> 5 records
#   Pair hit: Gretchen Alicea, PhD || Neil Vasan, MD, PhD -> 4 records
#   Pair hit: Hua Eleanor Yu, PhD || Jeremy Baskin, PhD -> 3 records
#   Pair hit: Hua Eleanor Yu, PhD || Livia  Schiavinato Eberlin, PhD -> 5 records
#   Pair hit: Hua Eleanor Yu, PhD || Neil Vasan, MD, PhD -> 4 records
#   Pair hit: Jeremy Baskin, PhD || Karen Dixon, -> 3 records
#   Pair hit: Jeremy Baskin, PhD || Livia  Schiavinato Eberlin, PhD -> 8 records
#   Pair hit: Jeremy Baskin, PhD || Neil Vasan, MD, PhD -> 7 records
#   Pair hit: Jeremy Baskin, PhD || Prof Banafshe  Larijani , PhD -> 3 records
#   Pair hit: Jeremy Baskin, PhD || Ray Blind, -> 3 records
#   Pair hit: Jeremy Baskin, PhD || Sarah  Skuli, -> 3 records
#   Pair hit: Jeremy Baskin, PhD || Tamas Balla, MD, PhD -> 3 records
#   Pair hit: Jeremy Baskin, PhD || Targeting Lipid Biology in Cancer -> 3 records
#   Pair hit: Jeremy Baskin, PhD || Vytas Bankaitis, PhD -> 3 records
#   Pair hit: Karen Dixon, || Livia  Schiavinato Eberlin, PhD -> 5 records
#   Pair hit: Karen Dixon, || Neil Vasan, MD, PhD -> 4 records
#   Pair hit: Livia  Schiavinato Eberlin, PhD || Neil Vasan, MD, PhD -> 9 records
#   Pair hit: Livia  Schiavinato Eberlin, PhD || Prof Banafshe  Larijani , PhD -> 5 records
#   Pair hit: Livia  Schiavinato Eberlin, PhD || Ray Blind, -> 5 records
#   Pair hit: Livia  Schiavinato Eberlin, PhD || Sarah  Skuli, -> 5 records
#   Pair hit: Livia  Schiavinato Eberlin, PhD || Tamas Balla, MD, PhD -> 5 records
#   Pair hit: Livia  Schiavinato Eberlin, PhD || Targeting Lipid Biology in Cancer -> 5 records
#   Pair hit: Livia  Schiavinato Eberlin, PhD || Vytas Bankaitis, PhD -> 5 records
#   Pair hit: Neil Vasan, MD, PhD || Prof Banafshe  Larijani , PhD -> 4 records
#   Pair hit: Neil Vasan, MD, PhD || Ray Blind, -> 4 records
#   Pair hit: Neil Vasan, MD, PhD || Sarah  Skuli, -> 4 records
#   Pair hit: Neil Vasan, MD, PhD || Tamas Balla, MD, PhD -> 4 records
#   Pair hit: Neil Vasan, MD, PhD || Targeting Lipid Biology in Cancer -> 4 records
#   Pair hit: Neil Vasan, MD, PhD || Vytas Bankaitis, PhD -> 4 records
#
# BIN SUMMARY
#   Pairs with ≥1 result: 62
#   Unique appl_ids in bin: 1
#   Summed award amount (unique appl_id only): $0
#
# -----------------------------------------------
# Bin: 2023–2028
# Fiscal years: 2023..2028
#   Pair hit: Alison Ringel, PhD || David Fruman, PhD -> 3 records
#   Pair hit: Alison Ringel, PhD || Jeremy Baskin, PhD -> 1 records
#   Pair hit: Alison Ringel, PhD || Livia  Schiavinato Eberlin, PhD -> 12 records
#   Pair hit: Alison Ringel, PhD || Neil Vasan, MD, PhD -> 2 records
#   Pair hit: Bart Vanhaesebroeck, PhD || David Fruman, PhD -> 3 records
#   Pair hit: Bart Vanhaesebroeck, PhD || Jeremy Baskin, PhD -> 1 records
#   Pair hit: Bart Vanhaesebroeck, PhD || Livia  Schiavinato Eberlin, PhD -> 12 records
#   Pair hit: Bart Vanhaesebroeck, PhD || Neil Vasan, MD, PhD -> 2 records
#   Pair hit: Brooke Emerling, PhD || David Fruman, PhD -> 3 records
#   Pair hit: Brooke Emerling, PhD || Jeremy Baskin, PhD -> 1 records
#   Pair hit: Brooke Emerling, PhD || Livia  Schiavinato Eberlin, PhD -> 12 records
#   Pair hit: Brooke Emerling, PhD || Neil Vasan, MD, PhD -> 2 records
#   Pair hit: Christina Mitchell, MB BS, PhD || David Fruman, PhD -> 3 records
#   Pair hit: Christina Mitchell, MB BS, PhD || Jeremy Baskin, PhD -> 1 records
#   Pair hit: Christina Mitchell, MB BS, PhD || Livia  Schiavinato Eberlin, PhD -> 12 records
#   Pair hit: Christina Mitchell, MB BS, PhD || Neil Vasan, MD, PhD -> 2 records
#   Pair hit: David Fruman, PhD || Emilio Hirsch, PhD -> 3 records
#   Pair hit: David Fruman, PhD || Gretchen Alicea, PhD -> 3 records
#   Pair hit: David Fruman, PhD || Hua Eleanor Yu, PhD -> 3 records
#   Pair hit: David Fruman, PhD || Jeremy Baskin, PhD -> 4 records
#   Pair hit: David Fruman, PhD || Karen Dixon, -> 3 records
#   Pair hit: David Fruman, PhD || Livia  Schiavinato Eberlin, PhD -> 15 records
#   Pair hit: David Fruman, PhD || Neil Vasan, MD, PhD -> 5 records
#   Pair hit: David Fruman, PhD || Prof Banafshe  Larijani , PhD -> 3 records
#   Pair hit: David Fruman, PhD || Ray Blind, -> 3 records
#   Pair hit: David Fruman, PhD || Sarah  Skuli, -> 3 records
#   Pair hit: David Fruman, PhD || Tamas Balla, MD, PhD -> 3 records
#   Pair hit: David Fruman, PhD || Targeting Lipid Biology in Cancer -> 3 records
#   Pair hit: David Fruman, PhD || Vytas Bankaitis, PhD -> 3 records
#   Pair hit: Emilio Hirsch, PhD || Jeremy Baskin, PhD -> 1 records
#   Pair hit: Emilio Hirsch, PhD || Livia  Schiavinato Eberlin, PhD -> 12 records
#   Pair hit: Emilio Hirsch, PhD || Neil Vasan, MD, PhD -> 2 records
#   Pair hit: Gretchen Alicea, PhD || Jeremy Baskin, PhD -> 1 records
#   Pair hit: Gretchen Alicea, PhD || Livia  Schiavinato Eberlin, PhD -> 12 records
#   Pair hit: Gretchen Alicea, PhD || Neil Vasan, MD, PhD -> 2 records
#   Pair hit: Hua Eleanor Yu, PhD || Jeremy Baskin, PhD -> 1 records
#   Pair hit: Hua Eleanor Yu, PhD || Livia  Schiavinato Eberlin, PhD -> 12 records
#   Pair hit: Hua Eleanor Yu, PhD || Neil Vasan, MD, PhD -> 2 records
#   Pair hit: Jeremy Baskin, PhD || Karen Dixon, -> 1 records
#   Pair hit: Jeremy Baskin, PhD || Livia  Schiavinato Eberlin, PhD -> 13 records
#   Pair hit: Jeremy Baskin, PhD || Neil Vasan, MD, PhD -> 3 records
#   Pair hit: Jeremy Baskin, PhD || Prof Banafshe  Larijani , PhD -> 1 records
#   Pair hit: Jeremy Baskin, PhD || Ray Blind, -> 1 records
#   Pair hit: Jeremy Baskin, PhD || Sarah  Skuli, -> 1 records
#   Pair hit: Jeremy Baskin, PhD || Tamas Balla, MD, PhD -> 1 records
#   Pair hit: Jeremy Baskin, PhD || Targeting Lipid Biology in Cancer -> 1 records
#   Pair hit: Jeremy Baskin, PhD || Vytas Bankaitis, PhD -> 1 records
#   Pair hit: Karen Dixon, || Livia  Schiavinato Eberlin, PhD -> 12 records
#   Pair hit: Karen Dixon, || Neil Vasan, MD, PhD -> 2 records
#   Pair hit: Livia  Schiavinato Eberlin, PhD || Neil Vasan, MD, PhD -> 14 records
#   Pair hit: Livia  Schiavinato Eberlin, PhD || Prof Banafshe  Larijani , PhD -> 12 records
#   Pair hit: Livia  Schiavinato Eberlin, PhD || Ray Blind, -> 12 records
#   Pair hit: Livia  Schiavinato Eberlin, PhD || Sarah  Skuli, -> 12 records
#   Pair hit: Livia  Schiavinato Eberlin, PhD || Tamas Balla, MD, PhD -> 12 records
#   Pair hit: Livia  Schiavinato Eberlin, PhD || Targeting Lipid Biology in Cancer -> 12 records
#   Pair hit: Livia  Schiavinato Eberlin, PhD || Vytas Bankaitis, PhD -> 12 records
#   Pair hit: Neil Vasan, MD, PhD || Prof Banafshe  Larijani , PhD -> 2 records
#   Pair hit: Neil Vasan, MD, PhD || Ray Blind, -> 2 records
#   Pair hit: Neil Vasan, MD, PhD || Sarah  Skuli, -> 2 records
#   Pair hit: Neil Vasan, MD, PhD || Tamas Balla, MD, PhD -> 2 records
#   Pair hit: Neil Vasan, MD, PhD || Targeting Lipid Biology in Cancer -> 2 records
#   Pair hit: Neil Vasan, MD, PhD || Vytas Bankaitis, PhD -> 2 records
#
# BIN SUMMARY
#   Pairs with ≥1 result: 62
#   Unique appl_ids in bin: 1
#   Summed award amount (unique appl_id only): $0
#
# -----------------------------------------------
# Bin: 2028–2033
# Fiscal years: 2028..2033
#
# BIN SUMMARY
#   Pairs with ≥1 result: 0
#   Unique appl_ids in bin: 0
#   Summed award amount (unique appl_id only): $0
#
# -----------------------------------------------
# Bin: 2033–2038
# Fiscal years: 2033..2038
#
# BIN SUMMARY
#   Pairs with ≥1 result: 0
#   Unique appl_ids in bin: 0
#   Summed award amount (unique appl_id only): $0
#
# === COMPLETE ===
#                                        MeetingYearKey  MeetingYear        Bin  \
# 0                         2005 Scholar Retreat (2005)         2005  2000-2005
# 1                         2005 Scholar Retreat (2005)         2005  2005-2010
# 2                         2005 Scholar Retreat (2005)         2005  2010-2015
# 3                         2005 Scholar Retreat (2005)         2005  2015-2020
# 4   3D Chromosomal Architecture and Nuclear Topolo...         2019  2014-2019
# 5   3D Chromosomal Architecture and Nuclear Topolo...         2019  2019-2024
# 6   3D Chromosomal Architecture and Nuclear Topolo...         2019  2024-2029
# 7   3D Chromosomal Architecture and Nuclear Topolo...         2019  2029-2034
# 8            Targeting Lipid Biology in Cancer (2023)         2023  2018-2023
# 9            Targeting Lipid Biology in Cancer (2023)         2023  2023-2028
# 10           Targeting Lipid Biology in Cancer (2023)         2023  2028-2033
# 11           Targeting Lipid Biology in Cancer (2023)         2023  2033-2038
#
#     Pairs_tested  Pairs_with_hits  Unique_appl_ids  Unique_award_amount_sum
# 0            136                0                0                        0
# 1            136               31                1                        0
# 2            136               91                1                        0
# 3            136              115                1                        0
# 4            276              185                1                        0
# 5            276              198                1                        0
# 6            276              171                1                        0
# 7            276                0                0                        0
# 8            153               62                1                        0
# 9            153               62                1                        0
# 10           153                0                0                        0
# 11           153                0                0                        0
