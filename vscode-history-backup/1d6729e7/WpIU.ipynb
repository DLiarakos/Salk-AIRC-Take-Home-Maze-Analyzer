# %%
# %pip install requests beautifulsoup4 pdfkit
# Out:
# Requirement already satisfied: requests in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (4.13.3)
# Requirement already satisfied: pdfkit in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (from requests) (2025.1.31)
# Requirement already satisfied: soupsieve>1.2 in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (from beautifulsoup4) (4.12.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import re
import requests
import pdfkit
from bs4 import BeautifulSoup
from pathlib import Path

# %%
def get_books_and_links(toc_url):
    response = requests.get(toc_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    books = {}
    current_book = None

    tags = soup.find_all(["h2", "ul"])
    i = 0
    while i < len(tags):
        tag = tags[i]

        if tag.name == "h2" and "Book" in tag.get_text():
            current_book = tag.get_text(strip=True)
            books[current_book] = []

            if i + 1 < len(tags) and tags[i + 1].name == "ul":
                ul = tags[i + 1]

                chapter_lis = ul.find_all("li", recursive=False)
                if len(chapter_lis) == 1 and chapter_lis[0].find("ul"):
                    chapter_lis = chapter_lis[0].find("ul").find_all("li", recursive=False)

                for li in chapter_lis:
                    a = li.find("a", href=True)
                    if a:
                        title = a.get_text(strip=True)
                        href = a["href"]
                        books[current_book].append((title, href))

                i += 1  # Skip the UL

        i += 1

    return books

# %%
def sanitize_filename(title, index):
    title = re.sub(r'[^\w\s-]', '', title)
    title = re.sub(r'\s+', '_', title.strip())
    return f"Chapter_{index:02d}_{title}.pdf"

# %%
options = {
    'quiet': '',
    'no-print-media-type': '',
    'disable-smart-shrinking': '',
    'disable-javascript': '',
    'load-error-handling': 'ignore',
    'load-media-error-handling': 'ignore'
}

# %%
def save_books_as_pdfs(books, output_dir=".", wkhtmltopdf_path=None):
    if wkhtmltopdf_path:
        config = pdfkit.configuration(wkhtmltopdf=wkhtmltopdf_path)
    else:
        config = None

    output_dir = Path(output_dir)

    # Add recommended options to avoid printer popup
    options = {
        'quiet': '',
        'no-print-media-type': '',
        'disable-smart-shrinking': '',
        'disable-javascript': '',
        'load-error-handling': 'ignore',
        'load-media-error-handling': 'ignore'
    }

    for book_title, chapters in books.items():
        print(f"\n📘 Saving {book_title}...")

        book_folder = output_dir / book_title.replace(" ", "_")
        book_folder.mkdir(exist_ok=True)

        for i, (chapter_title, url) in enumerate(chapters, start=1):
            file_name = sanitize_filename(chapter_title, i)
            file_path = book_folder / file_name
            print(f"  - Saving: {chapter_title} → {file_name}")

            try:
                pdfkit.from_url(url, str(file_path), configuration=config, options=options)
            except Exception as e:
                print(f"    ⚠️ Failed to save {chapter_title}: {e}")

# %%
import shutil
print(shutil.which("wkhtmltopdf"))
# Out:
# None

# %%
# Set this if wkhtmltopdf is not in PATH:
wkhtmltopdf_path = "C:/Program Files/wkhtmltox/bin/wkhtmltopdf.exe"

#wkhtmltopdf_path = None  # Set to path if needed
import shutil
print(shutil.which("wkhtmltopdf"))
toc_url = "https://practicalguidetoevil.wordpress.com/table-of-contents/"
books = get_books_and_links(toc_url)

# Optional: test only on Book 1
books = {k: v for k, v in books.items() if k == "Book 2"}

save_books_as_pdfs(books, output_dir=".", wkhtmltopdf_path=wkhtmltopdf_path)
# Out:
# None
#
# 📘 Saving Book 1...
#   - Saving: Prologue → Chapter_01_Prologue.pdf
#   - Saving: Chapter 1: Knife → Chapter_02_Chapter_1_Knife.pdf
#   - Saving: Chapter 2: Invitation → Chapter_03_Chapter_2_Invitation.pdf
#   - Saving: Chapter 3: Party → Chapter_04_Chapter_3_Party.pdf
#   - Saving: Chapter 4: Name → Chapter_05_Chapter_4_Name.pdf
#   - Saving: Chapter 5: Role → Chapter_06_Chapter_5_Role.pdf
#   - Saving: Chapter 6: Aspect → Chapter_07_Chapter_6_Aspect.pdf
#   - Saving: Chapter 7: Sword → Chapter_08_Chapter_7_Sword.pdf
#   - Saving: Chapter 8: Introduction → Chapter_09_Chapter_8_Introduction.pdf
#   - Saving: Chapter 9: Claimant → Chapter_10_Chapter_9_Claimant.pdf
#   - Saving: Chapter 10: Menace → Chapter_11_Chapter_10_Menace.pdf
#   - Saving: Chapter 11: Sucker Punch → Chapter_12_Chapter_11_Sucker_Punch.pdf
#   - Saving: Chapter 12: Squire → Chapter_13_Chapter_12_Squire.pdf
#   - Saving: Chapter 13: Order → Chapter_14_Chapter_13_Order.pdf
#   - Saving: Chapter 14: Villain → Chapter_15_Chapter_14_Villain.pdf
#   - Saving: Chapter 15: Company → Chapter_16_Chapter_15_Company.pdf
#   - Saving: Chapter 16: Game → Chapter_17_Chapter_16_Game.pdf
#   - Saving: Chapter 17: Set → Chapter_18_Chapter_17_Set.pdf
#   - Saving: Chapter 18: Match → Chapter_19_Chapter_18_Match.pdf
#   - Saving: Chapter 19: Pivot → Chapter_20_Chapter_19_Pivot.pdf
#   - Saving: Chapter 20: Rise → Chapter_21_Chapter_20_Rise.pdf
#   - Saving: Chapter 21: Fall → Chapter_22_Chapter_21_Fall.pdf
#   - Saving: Chapter 22: All According To → Chapter_23_Chapter_22_All_According_To.pdf
#   - Saving: Chapter 23: Morok’s Plan → Chapter_24_Chapter_23_Moroks_Plan.pdf
#   - Saving: Chapter 24: Aisha’s Plan → Chapter_25_Chapter_24_Aishas_Plan.pdf
#   - Saving: Chapter 25: Snatcher’s Plan → Chapter_26_Chapter_25_Snatchers_Plan.pdf
#   - Saving: Chapter 26: Juniper’s Plan → Chapter_27_Chapter_26_Junipers_Plan.pdf
#   - Saving: Chapter 27: Callow’s Plan → Chapter_28_Chapter_27_Callows_Plan.pdf
#   - Saving: Chapter 28: Win Condition → Chapter_29_Chapter_28_Win_Condition.pdf
#   - Saving: Epilogue → Chapter_30_Epilogue.pdf
