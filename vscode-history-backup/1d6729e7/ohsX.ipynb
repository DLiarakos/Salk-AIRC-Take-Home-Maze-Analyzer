# %%
# %pip install requests beautifulsoup4 pdfkit
# Out:
# Requirement already satisfied: requests in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (4.13.3)
# Requirement already satisfied: pdfkit in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (from requests) (2025.1.31)
# Requirement already satisfied: soupsieve>1.2 in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (from beautifulsoup4) (4.12.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import re
import requests
import pdfkit
from bs4 import BeautifulSoup
from pathlib import Path

# %%
def get_books_and_links(toc_url):
    response = requests.get(toc_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    books = {}
    current_book = None

    tags = soup.find_all(["h2", "ul"])
    i = 0
    while i < len(tags):
        tag = tags[i]

        if tag.name == "h2" and "Book" in tag.get_text():
            current_book = tag.get_text(strip=True)
            books[current_book] = []

            if i + 1 < len(tags) and tags[i + 1].name == "ul":
                ul = tags[i + 1]

                chapter_lis = ul.find_all("li", recursive=False)
                if len(chapter_lis) == 1 and chapter_lis[0].find("ul"):
                    chapter_lis = chapter_lis[0].find("ul").find_all("li", recursive=False)

                for li in chapter_lis:
                    a = li.find("a", href=True)
                    if a:
                        title = a.get_text(strip=True)
                        href = a["href"]
                        books[current_book].append((title, href))

                i += 1  # Skip the UL

        i += 1

    return books

# %%
def sanitize_filename(title, index):
    title = re.sub(r'[^\w\s-]', '', title)
    title = re.sub(r'\s+', '_', title.strip())
    return f"Chapter_{index:02d}_{title}.pdf"

# %%
options = {
    'quiet': '',
    'no-print-media-type': '',
    'disable-smart-shrinking': '',
    'disable-javascript': '',
    'load-error-handling': 'ignore',
    'load-media-error-handling': 'ignore'
}

# %%
def save_books_as_pdfs(books, output_dir=".", wkhtmltopdf_path=None):
    if wkhtmltopdf_path:
        config = pdfkit.configuration(wkhtmltopdf=wkhtmltopdf_path)
    else:
        config = None

    output_dir = Path(output_dir)

    # Add recommended options to avoid printer popup
    options = {
        'quiet': '',
        'no-print-media-type': '',
        'disable-smart-shrinking': '',
        'disable-javascript': '',
        'load-error-handling': 'ignore',
        'load-media-error-handling': 'ignore'
    }

    for book_title, chapters in books.items():
        print(f"\n📘 Saving {book_title}...")

        book_folder = output_dir / book_title.replace(" ", "_")
        book_folder.mkdir(exist_ok=True)

        for i, (chapter_title, url) in enumerate(chapters, start=1):
            file_name = sanitize_filename(chapter_title, i)
            file_path = book_folder / file_name
            print(f"  - Saving: {chapter_title} → {file_name}")

            try:
                pdfkit.from_url(url, str(file_path), configuration=config, options=options)
            except Exception as e:
                print(f"    ⚠️ Failed to save {chapter_title}: {e}")

# %%
import shutil
print(shutil.which("wkhtmltopdf"))
# Out:
# None

# %%
# Set this if wkhtmltopdf is not in PATH:
wkhtmltopdf_path = "C:/Program Files/wkhtmltox/bin/wkhtmltopdf.exe"

#wkhtmltopdf_path = None  # Set to path if needed
import shutil
print(shutil.which("wkhtmltopdf"))
toc_url = "https://practicalguidetoevil.wordpress.com/table-of-contents/"
books = get_books_and_links(toc_url)

# Optional: test only on Book 1
books = {k: v for k, v in books.items() if k == "Book 3"}

save_books_as_pdfs(books, output_dir=".", wkhtmltopdf_path=wkhtmltopdf_path)
# Out:
# None
#
# 📘 Saving Book 2...
#   - Saving: Prologue → Chapter_01_Prologue.pdf
#   - Saving: Chapter 1: Supply → Chapter_02_Chapter_1_Supply.pdf
#   - Saving: Chapter 2: Demand → Chapter_03_Chapter_2_Demand.pdf
#   - Saving: Chapter 3: Cost → Chapter_04_Chapter_3_Cost.pdf
#   - Saving: Heroic Interlude: Balestra → Chapter_05_Heroic_Interlude_Balestra.pdf
#   - Saving: Chapter 4: Return → Chapter_06_Chapter_4_Return.pdf
#   - Saving: Chapter 5: Recognition → Chapter_07_Chapter_5_Recognition.pdf
#   - Saving: Chapter 6: Rapport → Chapter_08_Chapter_6_Rapport.pdf
#   - Saving: Chapter 7: Reception → Chapter_09_Chapter_7_Reception.pdf
#   - Saving: Chapter 8: Reversal → Chapter_10_Chapter_8_Reversal.pdf
#   - Saving: Chapter 9: Rematch → Chapter_11_Chapter_9_Rematch.pdf
#   - Saving: Chapter 10: Release → Chapter_12_Chapter_10_Release.pdf
#   - Saving: Chapter 11: Report → Chapter_13_Chapter_11_Report.pdf
#   - Saving: Chapter 12: Reproval → Chapter_14_Chapter_12_Reproval.pdf
#   - Saving: Heroic Interlude: Riposte → Chapter_15_Heroic_Interlude_Riposte.pdf
#   - Saving: Villainous Interlude: Coulisse → Chapter_16_Villainous_Interlude_Coulisse.pdf
#   - Saving: Chapter 13: Fireside → Chapter_17_Chapter_13_Fireside.pdf
#   - Saving: Chapter 14: Situation → Chapter_18_Chapter_14_Situation.pdf
#   - Saving: Chapter 15: Council → Chapter_19_Chapter_15_Council.pdf
#   - Saving: Chapter 16: Trust → Chapter_20_Chapter_16_Trust.pdf
#   - Saving: Chapter 17: Aplomb → Chapter_21_Chapter_17_Aplomb.pdf
#   - Saving: Chapter 18: Tinder → Chapter_22_Chapter_18_Tinder.pdf
#   - Saving: Chapter 19: Flame → Chapter_23_Chapter_19_Flame.pdf
#   - Saving: Chapter 20: Ashes → Chapter_24_Chapter_20_Ashes.pdf
#   - Saving: Chapter 21: Marchford → Chapter_25_Chapter_21_Marchford.pdf
#   - Saving: Villainous Interlude: Coup de Théatre → Chapter_26_Villainous_Interlude_Coup_de_Théatre.pdf
#   - Saving: Heroic Interlude: Attaque au Fer → Chapter_27_Heroic_Interlude_Attaque_au_Fer.pdf
#   - Saving: Chapter 22: Rescue → Chapter_28_Chapter_22_Rescue.pdf
#   - Saving: Chapter 23: Defeat → Chapter_29_Chapter_23_Defeat.pdf
#   - Saving: Chapter 24: Archer → Chapter_30_Chapter_24_Archer.pdf
#   - Saving: Chapter 25: Wake → Chapter_31_Chapter_25_Wake.pdf
#   - Saving: Chapter 26: Seek → Chapter_32_Chapter_26_Seek.pdf
#   - Saving: Chapter 27: Cut → Chapter_33_Chapter_27_Cut.pdf
#   - Saving: Chapter 28: Prelude → Chapter_34_Chapter_28_Prelude.pdf
#   - Saving: Interlude: Greenskins → Chapter_35_Interlude_Greenskins.pdf
#   - Saving: Chapter 29: Stand → Chapter_36_Chapter_29_Stand.pdf
#   - Saving: Chapter 30: Deliver → Chapter_37_Chapter_30_Deliver.pdf
#   - Saving: Chapter 31: Sleight → Chapter_38_Chapter_31_Sleight.pdf
#   - Saving: Chapter 32: Draw → Chapter_39_Chapter_32_Draw.pdf
#   - Saving: Chapter 33: Clean-up → Chapter_40_Chapter_33_Clean-up.pdf
#   - Saving: Chapter 34: Lesson → Chapter_41_Chapter_34_Lesson.pdf
#   - Saving: Chapter 35: Spur → Chapter_42_Chapter_35_Spur.pdf
#   - Saving: Chapter 36: Madman → Chapter_43_Chapter_36_Madman.pdf
#   - Saving: Interlude: Nemeses → Chapter_44_Interlude_Nemeses.pdf
#   - Saving: Chapter 37: Apprentice → Chapter_45_Chapter_37_Apprentice.pdf
#   - Saving: Chapter 38: Juncture → Chapter_46_Chapter_38_Juncture.pdf
#   - Saving: Villainous Interlude: Impresario → Chapter_47_Villainous_Interlude_Impresario.pdf
#   - Saving: Interlude: Rats → Chapter_48_Interlude_Rats.pdf
#   - Saving: Chapter 39: Countdown → Chapter_49_Chapter_39_Countdown.pdf
#   - Saving: Heroic Interlude: Prise au Fer → Chapter_50_Heroic_Interlude_Prise_au_Fer.pdf
#   - Saving: Chapter 40: Knock → Chapter_51_Chapter_40_Knock.pdf
#   - Saving: Chapter 41: Retrieve → Chapter_52_Chapter_41_Retrieve.pdf
#   - Saving: Chapter 42: Flaw → Chapter_53_Chapter_42_Flaw.pdf
#   - Saving: Chapter 43: Truce → Chapter_54_Chapter_43_Truce.pdf
#   - Saving: Chapter 44: Victory → Chapter_55_Chapter_44_Victory.pdf
#   - Saving: Chapter 45: Corpses → Chapter_56_Chapter_45_Corpses.pdf
#   - Saving: Chapter 46: Squire (Redux) → Chapter_57_Chapter_46_Squire_Redux.pdf
#   - Saving: Chapter 47: And Justice For All → Chapter_58_Chapter_47_And_Justice_For_All.pdf
#   - Saving: Chapter 48: Threes → Chapter_59_Chapter_48_Threes.pdf
#   - Saving: Chapter 49: Triumph → Chapter_60_Chapter_49_Triumph.pdf
#   - Saving: Interlude: Precipitation → Chapter_61_Interlude_Precipitation.pdf
#   - Saving: Epilogue → Chapter_62_Epilogue.pdf
