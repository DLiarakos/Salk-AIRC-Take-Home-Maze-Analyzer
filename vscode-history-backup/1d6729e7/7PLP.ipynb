# %%
# %pip install requests beautifulsoup4 pdfkit
# Out:
# Requirement already satisfied: requests in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (4.13.3)
# Requirement already satisfied: pdfkit in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (from requests) (2025.1.31)
# Requirement already satisfied: soupsieve>1.2 in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (from beautifulsoup4) (4.12.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import re
import requests
import pdfkit
from bs4 import BeautifulSoup
from pathlib import Path

# %%
def get_books_and_links(toc_url):
    response = requests.get(toc_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    books = {}
    current_book = None

    tags = soup.find_all(["h2", "ul"])
    i = 0
    while i < len(tags):
        tag = tags[i]

        if tag.name == "h2" and "Book" in tag.get_text():
            current_book = tag.get_text(strip=True)
            books[current_book] = []

            if i + 1 < len(tags) and tags[i + 1].name == "ul":
                ul = tags[i + 1]

                chapter_lis = ul.find_all("li", recursive=False)
                if len(chapter_lis) == 1 and chapter_lis[0].find("ul"):
                    chapter_lis = chapter_lis[0].find("ul").find_all("li", recursive=False)

                for li in chapter_lis:
                    a = li.find("a", href=True)
                    if a:
                        title = a.get_text(strip=True)
                        href = a["href"]
                        books[current_book].append((title, href))

                i += 1  # Skip the UL

        i += 1

    return books

# %%
def sanitize_filename(title, index):
    title = re.sub(r'[^\w\s-]', '', title)
    title = re.sub(r'\s+', '_', title.strip())
    return f"Chapter_{index:02d}_{title}.pdf"

# %%
options = {
    'quiet': '',
    'no-print-media-type': '',
    'disable-smart-shrinking': '',
    'disable-javascript': '',
    'load-error-handling': 'ignore',
    'load-media-error-handling': 'ignore'
}

# %%
def save_books_as_pdfs(books, output_dir=".", wkhtmltopdf_path=None):
    if wkhtmltopdf_path:
        config = pdfkit.configuration(wkhtmltopdf=wkhtmltopdf_path)
    else:
        config = None

    output_dir = Path(output_dir)

    # Add recommended options to avoid printer popup
    options = {
        'quiet': '',
        'no-print-media-type': '',
        'disable-smart-shrinking': '',
        'disable-javascript': '',
        'load-error-handling': 'ignore',
        'load-media-error-handling': 'ignore'
    }

    for book_title, chapters in books.items():
        print(f"\n📘 Saving {book_title}...")

        book_folder = output_dir / book_title.replace(" ", "_")
        book_folder.mkdir(exist_ok=True)

        for i, (chapter_title, url) in enumerate(chapters, start=1):
            file_name = sanitize_filename(chapter_title, i)
            file_path = book_folder / file_name
            print(f"  - Saving: {chapter_title} → {file_name}")

            try:
                pdfkit.from_url(url, str(file_path), configuration=config, options=options)
            except Exception as e:
                print(f"    ⚠️ Failed to save {chapter_title}: {e}")

# %%
import shutil
print(shutil.which("wkhtmltopdf"))
# Out:
# None

# %%
# Set this if wkhtmltopdf is not in PATH:
wkhtmltopdf_path = "C:/Program Files/wkhtmltox/bin/wkhtmltopdf.exe"

#wkhtmltopdf_path = None  # Set to path if needed
import shutil
print(shutil.which("wkhtmltopdf"))
toc_url = "https://practicalguidetoevil.wordpress.com/table-of-contents/"
books = get_books_and_links(toc_url)

# Optional: test only on Book 1
books = {k: v for k, v in books.items() if k == "Book 6"}

save_books_as_pdfs(books, output_dir=".", wkhtmltopdf_path=wkhtmltopdf_path)
# Out:
# None
#
# 📘 Saving Book 5...
#   - Saving: Prologue → Chapter_01_Prologue.pdf
#   - Saving: Chapter 1: Visitation → Chapter_02_Chapter_1_Visitation.pdf
#   - Saving: Chapter 2: Stirrings → Chapter_03_Chapter_2_Stirrings.pdf
#   - Saving: Chapter 3: Orison → Chapter_04_Chapter_3_Orison.pdf
#   - Saving: Chapter 4: Reconnoiter → Chapter_05_Chapter_4_Reconnoiter.pdf
#   - Saving: Chapter 5: Consult → Chapter_06_Chapter_5_Consult.pdf
#   - Saving: Chapter 6: Furor → Chapter_07_Chapter_6_Furor.pdf
#   - Saving: Chapter 7: Fellowship → Chapter_08_Chapter_7_Fellowship.pdf
#   - Saving: Chapter 8: Veracity → Chapter_09_Chapter_8_Veracity.pdf
#   - Saving: Chapter 9: Patient Knives → Chapter_10_Chapter_9_Patient_Knives.pdf
#   - Saving: Chapter 10: Capture → Chapter_11_Chapter_10_Capture.pdf
#   - Saving: Chapter 11: Forced March → Chapter_12_Chapter_11_Forced_March.pdf
#   - Saving: Chapter 12: Relief → Chapter_13_Chapter_12_Relief.pdf
#   - Saving: Interlude: Beheld I → Chapter_14_Interlude_Beheld_I.pdf
#   - Saving: Interlude: Beheld II → Chapter_15_Interlude_Beheld_II.pdf
#   - Saving: Chapter 13: Following → Chapter_16_Chapter_13_Following.pdf
#   - Saving: Chapter 14: Expedience → Chapter_17_Chapter_14_Expedience.pdf
#   - Saving: Chapter 15: Bereavement → Chapter_18_Chapter_15_Bereavement.pdf
#   - Saving: Chapter 16: Adverse → Chapter_19_Chapter_16_Adverse.pdf
#   - Saving: Chapter 17: Cloaks → Chapter_20_Chapter_17_Cloaks.pdf
#   - Saving: Interlude: Congregation I → Chapter_21_Interlude_Congregation_I.pdf
#   - Saving: Interlude: Congregation II → Chapter_22_Interlude_Congregation_II.pdf
#   - Saving: Interlude: Congregation III → Chapter_23_Interlude_Congregation_III.pdf
#   - Saving: Chapter 18: Fable → Chapter_24_Chapter_18_Fable.pdf
#   - Saving: Chapter 19: Precedent → Chapter_25_Chapter_19_Precedent.pdf
#   - Saving: Chapter 20: Bearings → Chapter_26_Chapter_20_Bearings.pdf
#   - Saving: Chapter 21: Intervention → Chapter_27_Chapter_21_Intervention.pdf
#   - Saving: Chapter 22: Standoffs → Chapter_28_Chapter_22_Standoffs.pdf
#   - Saving: Chapter 23: Readjustment → Chapter_29_Chapter_23_Readjustment.pdf
#   - Saving: Chapter 24: Theft → Chapter_30_Chapter_24_Theft.pdf
#   - Saving: Chapter 25: Dead Ends → Chapter_31_Chapter_25_Dead_Ends.pdf
#   - Saving: Chapter 26: Civility → Chapter_32_Chapter_26_Civility.pdf
#   - Saving: Chapter 27: Overtures → Chapter_33_Chapter_27_Overtures.pdf
#   - Saving: Chapter 28: Acts → Chapter_34_Chapter_28_Acts.pdf
#   - Saving: Chapter 29: Retrospect → Chapter_35_Chapter_29_Retrospect.pdf
#   - Saving: Chapter 30: Weaver; Woven → Chapter_36_Chapter_30_Weaver_Woven.pdf
#   - Saving: Chapter 31: Fall or Flight → Chapter_37_Chapter_31_Fall_or_Flight.pdf
#   - Saving: Interlude: West, Ever Pursuing → Chapter_38_Interlude_West_Ever_Pursuing.pdf
#   - Saving: Interlude: Graves We Have Yet To Fill → Chapter_39_Interlude_Graves_We_Have_Yet_To_Fill.pdf
#   - Saving: Interlude: Trust Is The Wager → Chapter_40_Interlude_Trust_Is_The_Wager.pdf
#   - Saving: Interlude: Death They Cannot Steal → Chapter_41_Interlude_Death_They_Cannot_Steal.pdf
#   - Saving: Interlude: And Pay Your Toll → Chapter_42_Interlude_And_Pay_Your_Toll.pdf
#   - Saving: Interlude: When Iron Rests → Chapter_43_Interlude_When_Iron_Rests.pdf
#   - Saving: Interlude: So We Shot Him → Chapter_44_Interlude_So_We_Shot_Him.pdf
#   - Saving: Chapter 32: Woven; Weaver → Chapter_45_Chapter_32_Woven_Weaver.pdf
#   - Saving: Chapter 33: Concord → Chapter_46_Chapter_33_Concord.pdf
#   - Saving: Chapter 34: Seven → Chapter_47_Chapter_34_Seven.pdf
#   - Saving: Chapter 35: Colloquy → Chapter_48_Chapter_35_Colloquy.pdf
#   - Saving: Chapter 36: Bid → Chapter_49_Chapter_36_Bid.pdf
#   - Saving: Chapter 37: Accessory → Chapter_50_Chapter_37_Accessory.pdf
#   - Saving: Chapter 38: Pinnacle → Chapter_51_Chapter_38_Pinnacle.pdf
#   - Saving: Chapter 39: Looting → Chapter_52_Chapter_39_Looting.pdf
#   - Saving: Chapter 40: Entreaty → Chapter_53_Chapter_40_Entreaty.pdf
#   - Saving: Chapter 41: Ante → Chapter_54_Chapter_41_Ante.pdf
#   - Saving: Chapter 42: Twined → Chapter_55_Chapter_42_Twined.pdf
#   - Saving: Chapter 43: Treachery → Chapter_56_Chapter_43_Treachery.pdf
#   - Saving: Chapter 44: Small Slights → Chapter_57_Chapter_44_Small_Slights.pdf
#   - Saving: Chapter 45: Long Prices → Chapter_58_Chapter_45_Long_Prices.pdf
#   - Saving: Interlude: Repudiation → Chapter_59_Interlude_Repudiation.pdf
#   - Saving: Interlude: Renunciation → Chapter_60_Interlude_Renunciation.pdf
#   - Saving: Interlude: Repurpose → Chapter_61_Interlude_Repurpose.pdf
#   - Saving: Interlude: Reckoning → Chapter_62_Interlude_Reckoning.pdf
#   - Saving: Interlude: Reverberation → Chapter_63_Interlude_Reverberation.pdf
#   - Saving: Chapter 46: Abdication → Chapter_64_Chapter_46_Abdication.pdf
#   - Saving: Chapter 47: Tenet → Chapter_65_Chapter_47_Tenet.pdf
#   - Saving: Chapter 48: Swan Song (Redux) → Chapter_66_Chapter_48_Swan_Song_Redux.pdf
#   - Saving: Chapter 49: Cracked → Chapter_67_Chapter_49_Cracked.pdf
#   - Saving: Chapter 50: Sunset → Chapter_68_Chapter_50_Sunset.pdf
#   - Saving: Chapter 51: Twilight → Chapter_69_Chapter_51_Twilight.pdf
#   - Saving: Interlude: Concourse I → Chapter_70_Interlude_Concourse_I.pdf
#   - Saving: Interlude: Concourse II → Chapter_71_Interlude_Concourse_II.pdf
#   - Saving: Interlude: Concourse III → Chapter_72_Interlude_Concourse_III.pdf
#   - Saving: Interlude: Concourse IV → Chapter_73_Interlude_Concourse_IV.pdf
#   - Saving: Interlude: Concourse V → Chapter_74_Interlude_Concourse_V.pdf
#   - Saving: Chapter 52: Recovery → Chapter_75_Chapter_52_Recovery.pdf
#   - Saving: Chapter 53: Avowed → Chapter_76_Chapter_53_Avowed.pdf
#   - Saving: Chapter 54: Lustrate → Chapter_77_Chapter_54_Lustrate.pdf
#   - Saving: Chapter 55: Renewal → Chapter_78_Chapter_55_Renewal.pdf
#   - Saving: Chapter 56: Reflections → Chapter_79_Chapter_56_Reflections.pdf
#   - Saving: Chapter 57: Hearing → Chapter_80_Chapter_57_Hearing.pdf
#   - Saving: Chapter 58: Prolong → Chapter_81_Chapter_58_Prolong.pdf
#   - Saving: Chapter 59: Review → Chapter_82_Chapter_59_Review.pdf
#   - Saving: Chapter 60: Melancholy → Chapter_83_Chapter_60_Melancholy.pdf
#   - Saving: Chapter 61: Reformation → Chapter_84_Chapter_61_Reformation.pdf
#   - Saving: Chapter 62: Pledged → Chapter_85_Chapter_62_Pledged.pdf
#   - Saving: Chapter 63: Draft → Chapter_86_Chapter_63_Draft.pdf
#   - Saving: Chapter 64: Breathe → Chapter_87_Chapter_64_Breathe.pdf
#   - Saving: Chapter 65: Convivial → Chapter_88_Chapter_65_Convivial.pdf
#   - Saving: Chapter 66: Silvered → Chapter_89_Chapter_66_Silvered.pdf
#   - Saving: Chapter 67: Starlight → Chapter_90_Chapter_67_Starlight.pdf
#   - Saving: Chapter 68: Apropos → Chapter_91_Chapter_68_Apropos.pdf
#   - Saving: Chapter 69: Repute → Chapter_92_Chapter_69_Repute.pdf
#   - Saving: Chapter 70: Dawning → Chapter_93_Chapter_70_Dawning.pdf
#   - Saving: Chapter 71: Verge → Chapter_94_Chapter_71_Verge.pdf
#   - Saving: Interlude: Iron → Chapter_95_Interlude_Iron.pdf
#   - Saving: Interlude: Rope → Chapter_96_Interlude_Rope.pdf
#   - Saving: Interlude: Candle → Chapter_97_Interlude_Candle.pdf
#   - Saving: Interlude: Harp → Chapter_98_Interlude_Harp.pdf
#   - Saving: Interlude: Bone → Chapter_99_Interlude_Bone.pdf
#   - Saving: Interlude: Mirror → Chapter_100_Interlude_Mirror.pdf
#   - Saving: Interlude: And Yet We Stand → Chapter_101_Interlude_And_Yet_We_Stand.pdf
#   - Saving: Chapter 72: Rumours → Chapter_102_Chapter_72_Rumours.pdf
#   - Saving: Chapter 73: Discerning → Chapter_103_Chapter_73_Discerning.pdf
#   - Saving: Chapter 74: Partial → Chapter_104_Chapter_74_Partial.pdf
#   - Saving: Chapter 75: Analog → Chapter_105_Chapter_75_Analog.pdf
#   - Saving: Chapter 76: Procession → Chapter_106_Chapter_76_Procession.pdf
#   - Saving: Chapter 77: Artless → Chapter_107_Chapter_77_Artless.pdf
#   - Saving: Chapter 78: Trenchant → Chapter_108_Chapter_78_Trenchant.pdf
#   - Saving: Chapter 79: Hitch → Chapter_109_Chapter_79_Hitch.pdf
#   - Saving: Chapter 80: Descant → Chapter_110_Chapter_80_Descant.pdf
#   - Saving: Chapter 81: Devotional → Chapter_111_Chapter_81_Devotional.pdf
#   - Saving: Chapter 82: Delegations → Chapter_112_Chapter_82_Delegations.pdf
#   - Saving: Chapter 83: A Mould Unbroken → Chapter_113_Chapter_83_A_Mould_Unbroken.pdf
#   - Saving: Interlude: Rise, Rise → Chapter_114_Interlude_Rise_Rise.pdf
#   - Saving: Interlude: All Ye Villains → Chapter_115_Interlude_All_Ye_Villains.pdf
#   - Saving: Interlude: So Smile, Tyrants → Chapter_116_Interlude_So_Smile_Tyrants.pdf
#   - Saving: Interlude: And So Let Us Be → Chapter_117_Interlude_And_So_Let_Us_Be.pdf
#     ⚠️ Failed to save Interlude: And So Let Us Be: wkhtmltopdf reported an error:
# Exit with code 1 due to network error: UnknownContentError
#
#   - Saving: Interlude: Wicked → Chapter_118_Interlude_Wicked.pdf
#   - Saving: Interlude: Suffer No Compromise In This → Chapter_119_Interlude_Suffer_No_Compromise_In_This.pdf
#   - Saving: Interlude: A Hundred Battles → Chapter_120_Interlude_A_Hundred_Battles.pdf
#   - Saving: Chapter 84: Declaration → Chapter_121_Chapter_84_Declaration.pdf
#   - Saving: Chapter 85: When It Rains → Chapter_122_Chapter_85_When_It_Rains.pdf
#   - Saving: Chapter 86: It Pours → Chapter_123_Chapter_86_It_Pours.pdf
#   - Saving: Chapter 87: Connive → Chapter_124_Chapter_87_Connive.pdf
#   - Saving: Chapter 88: Testament → Chapter_125_Chapter_88_Testament.pdf
#   - Saving: Chapter 89: Sing We Of Ruin → Chapter_126_Chapter_89_Sing_We_Of_Ruin.pdf
#   - Saving: Epilogue → Chapter_127_Epilogue.pdf
