# %%
# %pip install requests beautifulsoup4 pdfkit
# Out:
# Requirement already satisfied: requests in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (4.13.3)
# Requirement already satisfied: pdfkit in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (from requests) (2025.1.31)
# Requirement already satisfied: soupsieve>1.2 in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\david\anaconda3\envs\rosetta_new_project\lib\site-packages (from beautifulsoup4) (4.12.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import re
import requests
import pdfkit
from bs4 import BeautifulSoup
from pathlib import Path

# %%
def get_books_and_links(toc_url):
    response = requests.get(toc_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    books = {}
    current_book = None

    tags = soup.find_all(["h2", "ul"])
    i = 0
    while i < len(tags):
        tag = tags[i]

        if tag.name == "h2" and "Book" in tag.get_text():
            current_book = tag.get_text(strip=True)
            books[current_book] = []

            if i + 1 < len(tags) and tags[i + 1].name == "ul":
                ul = tags[i + 1]

                chapter_lis = ul.find_all("li", recursive=False)
                if len(chapter_lis) == 1 and chapter_lis[0].find("ul"):
                    chapter_lis = chapter_lis[0].find("ul").find_all("li", recursive=False)

                for li in chapter_lis:
                    a = li.find("a", href=True)
                    if a:
                        title = a.get_text(strip=True)
                        href = a["href"]
                        books[current_book].append((title, href))

                i += 1  # Skip the UL

        i += 1

    return books

# %%
def sanitize_filename(title, index):
    title = re.sub(r'[^\w\s-]', '', title)
    title = re.sub(r'\s+', '_', title.strip())
    return f"Chapter_{index:02d}_{title}.pdf"

# %%
options = {
    'quiet': '',
    'no-print-media-type': '',
    'disable-smart-shrinking': '',
    'disable-javascript': '',
    'load-error-handling': 'ignore',
    'load-media-error-handling': 'ignore'
}

# %%
def save_books_as_pdfs(books, output_dir=".", wkhtmltopdf_path=None):
    if wkhtmltopdf_path:
        config = pdfkit.configuration(wkhtmltopdf=wkhtmltopdf_path)
    else:
        config = None

    output_dir = Path(output_dir)

    # Add recommended options to avoid printer popup
    options = {
        'quiet': '',
        'no-print-media-type': '',
        'disable-smart-shrinking': '',
        'disable-javascript': '',
        'load-error-handling': 'ignore',
        'load-media-error-handling': 'ignore'
    }

    for book_title, chapters in books.items():
        print(f"\n📘 Saving {book_title}...")

        book_folder = output_dir / book_title.replace(" ", "_")
        book_folder.mkdir(exist_ok=True)

        for i, (chapter_title, url) in enumerate(chapters, start=1):
            file_name = sanitize_filename(chapter_title, i)
            file_path = book_folder / file_name
            print(f"  - Saving: {chapter_title} → {file_name}")

            try:
                pdfkit.from_url(url, str(file_path), configuration=config, options=options)
            except Exception as e:
                print(f"    ⚠️ Failed to save {chapter_title}: {e}")

# %%
import shutil
print(shutil.which("wkhtmltopdf"))
# Out:
# None

# %%
# Set this if wkhtmltopdf is not in PATH:
wkhtmltopdf_path = "C:/Program Files/wkhtmltox/bin/wkhtmltopdf.exe"

#wkhtmltopdf_path = None  # Set to path if needed
import shutil
print(shutil.which("wkhtmltopdf"))
toc_url = "https://practicalguidetoevil.wordpress.com/table-of-contents/"
books = get_books_and_links(toc_url)

# Optional: test only on Book 1
books = {k: v for k, v in books.items() if k == "Book 5"}

save_books_as_pdfs(books, output_dir=".", wkhtmltopdf_path=wkhtmltopdf_path)
# Out:
# None
#
# 📘 Saving Book 4...
#   - Saving: Prologue → Chapter_01_Prologue.pdf
#   - Saving: Interlude: Stairway → Chapter_02_Interlude_Stairway.pdf
#   - Saving: Chapter 1: Observatory → Chapter_03_Chapter_1_Observatory.pdf
#   - Saving: Chapter 2: Alarm → Chapter_04_Chapter_2_Alarm.pdf
#   - Saving: Chapter 3: Chat → Chapter_05_Chapter_3_Chat.pdf
#   - Saving: Chapter 4: Warpath → Chapter_06_Chapter_4_Warpath.pdf
#   - Saving: Chapter 5: Interests → Chapter_07_Chapter_5_Interests.pdf
#   - Saving: Chapter 6: Hedges → Chapter_08_Chapter_6_Hedges.pdf
#   - Saving: Chapter 7: Snares → Chapter_09_Chapter_7_Snares.pdf
#   - Saving: Chapter 8: Dialogue → Chapter_10_Chapter_8_Dialogue.pdf
#   - Saving: Interlude: Crusaders → Chapter_11_Interlude_Crusaders.pdf
#   - Saving: Chapter 9: Grand Pas → Chapter_12_Chapter_9_Grand_Pas.pdf
#   - Saving: Chapter 10: Allegro → Chapter_13_Chapter_10_Allegro.pdf
#   - Saving: Chapter 11: Ballon → Chapter_14_Chapter_11_Ballon.pdf
#   - Saving: Chapter 12: Cambré → Chapter_15_Chapter_12_Cambré.pdf
#   - Saving: Chapter 13: Élevé → Chapter_16_Chapter_13_Élevé.pdf
#   - Saving: Chapter 14: Arabesque → Chapter_17_Chapter_14_Arabesque.pdf
#   - Saving: Chapter 15: Bravura → Chapter_18_Chapter_15_Bravura.pdf
#   - Saving: Chapter 16: Pirouette → Chapter_19_Chapter_16_Pirouette.pdf
#   - Saving: Interlude: Kaleidoscope → Chapter_20_Interlude_Kaleidoscope.pdf
#   - Saving: Interlude: Kaleidoscope II → Chapter_21_Interlude_Kaleidoscope_II.pdf
#   - Saving: Interlude: Kaleidoscope III → Chapter_22_Interlude_Kaleidoscope_III.pdf
#   - Saving: Interlude: Kaleidoscope IV → Chapter_23_Interlude_Kaleidoscope_IV.pdf
#   - Saving: Interlude: Kaleidoscope V → Chapter_24_Interlude_Kaleidoscope_V.pdf
#   - Saving: Interlude: Kaleidoscope VI → Chapter_25_Interlude_Kaleidoscope_VI.pdf
#   - Saving: Chapter 17: Contingent → Chapter_26_Chapter_17_Contingent.pdf
#   - Saving: Chapter 18: Cradle → Chapter_27_Chapter_18_Cradle.pdf
#   - Saving: Chapter 19: Recovery → Chapter_28_Chapter_19_Recovery.pdf
#   - Saving: Chapter 20: Onset → Chapter_29_Chapter_20_Onset.pdf
#   - Saving: Chapter 21: Tug-of-War → Chapter_30_Chapter_21_Tug-of-War.pdf
#   - Saving: Chapter 22: Trip → Chapter_31_Chapter_22_Trip.pdf
#   - Saving: Interlude: Red The Flowers → Chapter_32_Interlude_Red_The_Flowers.pdf
#   - Saving: Interlude: Sing We Of Rage → Chapter_33_Interlude_Sing_We_Of_Rage.pdf
#   - Saving: Interlude: Lest Dawn Fail → Chapter_34_Interlude_Lest_Dawn_Fail.pdf
#   - Saving: Chapter 23: Recoup → Chapter_35_Chapter_23_Recoup.pdf
#   - Saving: Chapter 24: Invitation (Redux) → Chapter_36_Chapter_24_Invitation_Redux.pdf
#   - Saving: Chapter 25: Edge → Chapter_37_Chapter_25_Edge.pdf
#   - Saving: Chapter 26: Plunge → Chapter_38_Chapter_26_Plunge.pdf
#   - Saving: Chapter 27: Into Dusk → Chapter_39_Chapter_27_Into_Dusk.pdf
#   - Saving: Chapter 28: Archaic → Chapter_40_Chapter_28_Archaic.pdf
#   - Saving: Chapter 29: Sixth → Chapter_41_Chapter_29_Sixth.pdf
#   - Saving: Chapter 30: Witness → Chapter_42_Chapter_30_Witness.pdf
#   - Saving: Chapter 31: Spectation → Chapter_43_Chapter_31_Spectation.pdf
#   - Saving: Chapter 32: Kernel → Chapter_44_Chapter_32_Kernel.pdf
#   - Saving: Chapter 33: Keter → Chapter_45_Chapter_33_Keter.pdf
#   - Saving: Chapter 34: Abyss → Chapter_46_Chapter_34_Abyss.pdf
#   - Saving: Chapter 35: Stroll → Chapter_47_Chapter_35_Stroll.pdf
#   - Saving: Chapter 36: Enchère → Chapter_48_Chapter_36_Enchère.pdf
#   - Saving: Chapter 37: Offing → Chapter_49_Chapter_37_Offing.pdf
#   - Saving: Chapter 38: All According To (Redux) → Chapter_50_Chapter_38_All_According_To_Redux.pdf
#   - Saving: Chapter 39: Hakram’s Plan → Chapter_51_Chapter_39_Hakrams_Plan.pdf
#   - Saving: Chapter 40: Vivienne’s Plan → Chapter_52_Chapter_40_Viviennes_Plan.pdf
#   - Saving: Chapter 41: Akua’s Plan → Chapter_53_Chapter_41_Akuas_Plan.pdf
#   - Saving: Chapter 42: The Skein’s Plan → Chapter_54_Chapter_42_The_Skeins_Plan.pdf
#   - Saving: Chapter 43: Masego’s Plan → Chapter_55_Chapter_43_Masegos_Plan.pdf
#   - Saving: Chapter 44: Catherine’s Plan → Chapter_56_Chapter_44_Catherines_Plan.pdf
#   - Saving: Chapter 45: Ambush → Chapter_57_Chapter_45_Ambush.pdf
#   - Saving: Chapter 46: Possibly A Plan → Chapter_58_Chapter_46_Possibly_A_Plan.pdf
#   - Saving: Chapter 47: Culmination → Chapter_59_Chapter_47_Culmination.pdf
#   - Saving: Interlude: Empires → Chapter_60_Interlude_Empires.pdf
#   - Saving: Chapter 48: Shadows → Chapter_61_Chapter_48_Shadows.pdf
#   - Saving: Chapter 49: Wrangle → Chapter_62_Chapter_49_Wrangle.pdf
#   - Saving: Chapter 50: Partings → Chapter_63_Chapter_50_Partings.pdf
#   - Saving: Chapter 51: First Impressions → Chapter_64_Chapter_51_First_Impressions.pdf
#   - Saving: Chapter 52: Finesse → Chapter_65_Chapter_52_Finesse.pdf
#   - Saving: Chapter 53: Gloom → Chapter_66_Chapter_53_Gloom.pdf
#   - Saving: Chapter 54: Scavenger → Chapter_67_Chapter_54_Scavenger.pdf
#   - Saving: Chapter 55: Outskirts → Chapter_68_Chapter_55_Outskirts.pdf
#   - Saving: Chapter 56: Knock Knock → Chapter_69_Chapter_56_Knock_Knock.pdf
#   - Saving: Chapter 57: Betwixt → Chapter_70_Chapter_57_Betwixt.pdf
#   - Saving: Chapter 58: Quiet → Chapter_71_Chapter_58_Quiet.pdf
#   - Saving: Chapter 59: Audience → Chapter_72_Chapter_59_Audience.pdf
#   - Saving: Chapter 60: Profiteers → Chapter_73_Chapter_60_Profiteers.pdf
#   - Saving: Chapter 61: Remonstration → Chapter_74_Chapter_61_Remonstration.pdf
#   - Saving: Interlude: Queen’s Gambit, Offered → Chapter_75_Interlude_Queens_Gambit_Offered.pdf
#   - Saving: Interlude: Zwischenzug → Chapter_76_Interlude_Zwischenzug.pdf
#   - Saving: Interlude: Giuoco Pianissimo → Chapter_77_Interlude_Giuoco_Pianissimo.pdf
#   - Saving: Interlude: Zwischenzug II → Chapter_78_Interlude_Zwischenzug_II.pdf
#   - Saving: Interlude: Giuoco Pianissimio II → Chapter_79_Interlude_Giuoco_Pianissimio_II.pdf
#   - Saving: Interlude: Queen’s Gambit, Declined → Chapter_80_Interlude_Queens_Gambit_Declined.pdf
#   - Saving: Chapter 62: Impulse → Chapter_81_Chapter_62_Impulse.pdf
#   - Saving: Chapter 63: Initiation → Chapter_82_Chapter_63_Initiation.pdf
#   - Saving: Chapter 64: Momentum → Chapter_83_Chapter_64_Momentum.pdf
#   - Saving: Chapter 65: Impact → Chapter_84_Chapter_65_Impact.pdf
#   - Saving: Chapter 66: Tremors → Chapter_85_Chapter_66_Tremors.pdf
#   - Saving: Chapter 67: Breakthrough → Chapter_86_Chapter_67_Breakthrough.pdf
#   - Saving: Interlude: Heretics → Chapter_87_Interlude_Heretics.pdf
#   - Saving: Interlude: Dreadful → Chapter_88_Interlude_Dreadful.pdf
#   - Saving: Interlude: Apostates → Chapter_89_Interlude_Apostates.pdf
#   - Saving: Interlude: Apogee → Chapter_90_Interlude_Apogee.pdf
#   - Saving: Interlude: Inheritance → Chapter_91_Interlude_Inheritance.pdf
#   - Saving: Chapter 68: Poised → Chapter_92_Chapter_68_Poised.pdf
#   - Saving: Chapter 69: Peerage → Chapter_93_Chapter_69_Peerage.pdf
#   - Saving: Chapter 70: The Calm Before → Chapter_94_Chapter_70_The_Calm_Before.pdf
#   - Saving: Chapter 71: Ozone → Chapter_95_Chapter_71_Ozone.pdf
#   - Saving: Chapter 72: Outflow → Chapter_96_Chapter_72_Outflow.pdf
#   - Saving: Chapter 73: Feeder Bands → Chapter_97_Chapter_73_Feeder_Bands.pdf
#   - Saving: Chapter 74: Eyewall → Chapter_98_Chapter_74_Eyewall.pdf
#   - Saving: Chapter 75: The Eye → Chapter_99_Chapter_75_The_Eye.pdf
#   - Saving: Chapter 76: Storm Surge → Chapter_100_Chapter_76_Storm_Surge.pdf
#   - Saving: Chapter 77: What Goes Around → Chapter_101_Chapter_77_What_Goes_Around.pdf
#   - Saving: Chapter 78: Comes Around → Chapter_102_Chapter_78_Comes_Around.pdf
#   - Saving: Chapter 79: As Above → Chapter_103_Chapter_79_As_Above.pdf
#   - Saving: Chapter 80: So Below → Chapter_104_Chapter_80_So_Below.pdf
#   - Saving: Chapter 81: Only To The Just → Chapter_105_Chapter_81_Only_To_The_Just.pdf
#   - Saving: Chapter 82: Thrice Dead → Chapter_106_Chapter_82_Thrice_Dead.pdf
#   - Saving: Interlude: Triptych → Chapter_107_Interlude_Triptych.pdf
#   - Saving: Epilogue → Chapter_108_Epilogue.pdf
