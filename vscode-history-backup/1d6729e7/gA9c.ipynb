# %%
# %pip install requests beautifulsoup4

# %%
import re
import requests
from bs4 import BeautifulSoup
from pathlib import Path

# %%
def get_books_and_links(toc_url):
    response = requests.get(toc_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    books = {}
    current_book = None

    tags = soup.find_all(["h2", "ul"])
    i = 0
    while i < len(tags):
        tag = tags[i]

        if tag.name == "h2" and "Book" in tag.get_text():
            current_book = tag.get_text(strip=True)
            books[current_book] = []

            if i + 1 < len(tags) and tags[i + 1].name == "ul":
                ul = tags[i + 1]

                chapter_lis = ul.find_all("li", recursive=False)
                if len(chapter_lis) == 1 and chapter_lis[0].find("ul"):
                    chapter_lis = chapter_lis[0].find("ul").find_all("li", recursive=False)

                for li in chapter_lis:
                    a = li.find("a", href=True)
                    if a:
                        title = a.get_text(strip=True)
                        href = a["href"]
                        books[current_book].append((title, href))

                i += 1  # Skip the UL

        i += 1

    return books

# %%
def sanitize_filename(title, index):
    title = re.sub(r'[^\w\s-]', '', title)
    title = re.sub(r'\s+', '_', title.strip())
    return f"Chapter_{index:02d}_{title}.pdf"

# %%
def save_books_as_pdfs(books, output_dir=".", wkhtmltopdf_path=None):
    if wkhtmltopdf_path:
        config = pdfkit.configuration(wkhtmltopdf=wkhtmltopdf_path)
    else:
        config = None

    output_dir = Path(output_dir)

    options = {
        'quiet': '',
        'no-print-media-type': '',
        'disable-smart-shrinking': '',
        'disable-javascript': '',
        'load-error-handling': 'ignore',
        'load-media-error-handling': 'ignore'
    }

    for book_title, chapters in books.items():
        print(f"\n📘 Saving {book_title}...")

        book_folder = output_dir / book_title.replace(" ", "_")
        book_folder.mkdir(exist_ok=True)

        for i, (chapter_title, url) in enumerate(chapters, start=1):
            file_name = sanitize_filename(chapter_title, i)
            file_path = book_folder / file_name
            print(f"  - Saving: {chapter_title} → {file_name}")

            try:
                pdfkit.from_url(url, str(file_path), configuration=config, options=options)
            except Exception as e:
                print(f"    ⚠️ Failed to save {chapter_title}: {e}")

# %%
import shutil
print(shutil.which("wkhtmltopdf"))
# Out:
# None

# %%
# Set this if wkhtmltopdf is not in PATH:
wkhtmltopdf_path = "C:/Program Files/wkhtmltox/bin/wkhtmltopdf.exe"

import shutil
print(shutil.which("wkhtmltopdf"))
toc_url = "https://practicalguidetoevil.wordpress.com/table-of-contents/"
books = get_books_and_links(toc_url)

# download book by book
books = {k: v for k, v in books.items() if k == "Book 7"}

save_books_as_pdfs(books, output_dir=".", wkhtmltopdf_path=wkhtmltopdf_path)
# Out:
# None
#
# 📘 Saving Book 7...
#   - Saving: Prologue → Chapter_01_Prologue.pdf
#   - Saving: Chapter 1: Debut → Chapter_02_Chapter_1_Debut.pdf
#   - Saving: Chapter 2: Perplex → Chapter_03_Chapter_2_Perplex.pdf
#   - Saving: Chapter 3: Wage → Chapter_04_Chapter_3_Wage.pdf
#   - Saving: Chapter 4: Stock → Chapter_05_Chapter_4_Stock.pdf
#   - Saving: Chapter 5: Incursion → Chapter_06_Chapter_5_Incursion.pdf
#   - Saving: Chapter 6: Retaliation → Chapter_07_Chapter_6_Retaliation.pdf
#   - Saving: Chapter 7: Expatriate → Chapter_08_Chapter_7_Expatriate.pdf
#   - Saving: Chapter 8: Access → Chapter_09_Chapter_8_Access.pdf
#   - Saving: Chapter 9: Vault → Chapter_10_Chapter_9_Vault.pdf
#   - Saving: Chapter 10: Parley → Chapter_11_Chapter_10_Parley.pdf
#   - Saving: Chapter 11: Descent → Chapter_12_Chapter_11_Descent.pdf
#   - Saving: Interlude: West I → Chapter_13_Interlude_West_I.pdf
#   - Saving: Interlude: East I → Chapter_14_Interlude_East_I.pdf
#   - Saving: Chapter 12: String → Chapter_15_Chapter_12_String.pdf
#   - Saving: Chapter 13: Footing → Chapter_16_Chapter_13_Footing.pdf
#   - Saving: Chapter 14: Nock → Chapter_17_Chapter_14_Nock.pdf
#   - Saving: Chapter 15: Pull → Chapter_18_Chapter_15_Pull.pdf
#   - Saving: Interlude: North I → Chapter_19_Interlude_North_I.pdf
#   - Saving: Interlude: East II → Chapter_20_Interlude_East_II.pdf
#   - Saving: Chapter 16: Anchor → Chapter_21_Chapter_16_Anchor.pdf
#   - Saving: Chapter 17: Aim → Chapter_22_Chapter_17_Aim.pdf
#   - Saving: Chapter 18: Release → Chapter_23_Chapter_18_Release.pdf
#   - Saving: Chapter 19: Vivienne’s Plan (Redux) → Chapter_24_Chapter_19_Viviennes_Plan_Redux.pdf
#   - Saving: Chapter 20: Malicia’s Plan → Chapter_25_Chapter_20_Malicias_Plan.pdf
#   - Saving: Interlude: Juniper’s Plan (Redux) → Chapter_26_Interlude_Junipers_Plan_Redux.pdf
#   - Saving: Chapter 21: Amadeus’ Plan → Chapter_27_Chapter_21_Amadeus_Plan.pdf
#   - Saving: Interlude: South → Chapter_28_Interlude_South.pdf
#   - Saving: Interlude: North II → Chapter_29_Interlude_North_II.pdf
#   - Saving: Interlude: North III → Chapter_30_Interlude_North_III.pdf
#     ⚠️ Failed to save Interlude: North III: wkhtmltopdf reported an error:
# Exit with code 1 due to network error: ContentNotFoundError
#
#   - Saving: Interlude: West II → Chapter_31_Interlude_West_II.pdf
#   - Saving: Interlude: East III → Chapter_32_Interlude_East_III.pdf
#   - Saving: Chapter 22: Advent → Chapter_33_Chapter_22_Advent.pdf
#   - Saving: Chapter 23: Sung; Singer → Chapter_34_Chapter_23_Sung_Singer.pdf
#   - Saving: Chapter 24: Bequeathal → Chapter_35_Chapter_24_Bequeathal.pdf
#   - Saving: Chapter 25: Fool → Chapter_36_Chapter_25_Fool.pdf
#   - Saving: Interlude: A Tower No One Could Claim → Chapter_37_Interlude_A_Tower_No_One_Could_Claim.pdf
#   - Saving: Interlude: Burn Away What You Once Were → Chapter_38_Interlude_Burn_Away_What_You_Once_Were.pdf
#   - Saving: Interlude: The Hanged All Crooning → Chapter_39_Interlude_The_Hanged_All_Crooning.pdf
#   - Saving: Interlude: Kiss Of The Knife → Chapter_40_Interlude_Kiss_Of_The_Knife.pdf
#   - Saving: Interlude: Strangest And Most Solemn → Chapter_41_Interlude_Strangest_And_Most_Solemn.pdf
#   - Saving: Interlude: A Girl Without A Name → Chapter_42_Interlude_A_Girl_Without_A_Name.pdf
#   - Saving: Chapter 26: Singer; Sung → Chapter_43_Chapter_26_Singer_Sung.pdf
#   - Saving: Interlude: End Times → Chapter_44_Interlude_End_Times.pdf
#   - Saving: Chapter 27: Recoil → Chapter_45_Chapter_27_Recoil.pdf
#   - Saving: Chapter 28: Grieved → Chapter_46_Chapter_28_Grieved.pdf
#   - Saving: Chapter 29: Foundation → Chapter_47_Chapter_29_Foundation.pdf
#   - Saving: Chapter 30: Salute → Chapter_48_Chapter_30_Salute.pdf
#   - Saving: Chapter 31: Premises → Chapter_49_Chapter_31_Premises.pdf
#   - Saving: Chapter 32: Claimant (Redux) → Chapter_50_Chapter_32_Claimant_Redux.pdf
#   - Saving: Chapter 33: Claimant (Repeat) → Chapter_51_Chapter_33_Claimant_Repeat.pdf
#   - Saving: Chapter 34: Movements → Chapter_52_Chapter_34_Movements.pdf
#   - Saving: Chapter 35: Catch → Chapter_53_Chapter_35_Catch.pdf
#   - Saving: Chapter 36: Reiterate → Chapter_54_Chapter_36_Reiterate.pdf
#   - Saving: Chapter 37: Bygone → Chapter_55_Chapter_37_Bygone.pdf
#   - Saving: Chapter 38: Salvo → Chapter_56_Chapter_38_Salvo.pdf
#   - Saving: Interlude: Occidental I → Chapter_57_Interlude_Occidental_I.pdf
#   - Saving: Interlude: Occidental II → Chapter_58_Interlude_Occidental_II.pdf
#   - Saving: Interlude: Occidental III → Chapter_59_Interlude_Occidental_III.pdf
#   - Saving: Interlude: Occidental IV → Chapter_60_Interlude_Occidental_IV.pdf
#   - Saving: Interlude: Occidental V → Chapter_61_Interlude_Occidental_V.pdf
#   - Saving: Chapter 39: Name (Redux) → Chapter_62_Chapter_39_Name_Redux.pdf
#   - Saving: Chapter 40: Resolutions → Chapter_63_Chapter_40_Resolutions.pdf
#   - Saving: Chapter 41: Passing → Chapter_64_Chapter_41_Passing.pdf
#   - Saving: Chapter 42: Journey → Chapter_65_Chapter_42_Journey.pdf
#   - Saving: Chapter 43: Serolen → Chapter_66_Chapter_43_Serolen.pdf
#   - Saving: Chapter 44: Antecedents → Chapter_67_Chapter_44_Antecedents.pdf
#   - Saving: Chapter 45: Kernel (Redux) → Chapter_68_Chapter_45_Kernel_Redux.pdf
#   - Saving: Chapter 46: Penultimate → Chapter_69_Chapter_46_Penultimate.pdf
#   - Saving: Chapter 47: Hollow; Hallow → Chapter_70_Chapter_47_Hollow_Hallow.pdf
#   - Saving: Chapter 48: Root → Chapter_71_Chapter_48_Root.pdf
#   - Saving: Interlude: End Times II → Chapter_72_Interlude_End_Times_II.pdf
#   - Saving: Chapter 49: Arrival → Chapter_73_Chapter_49_Arrival.pdf
#   - Saving: Chapter 50: Clouds → Chapter_74_Chapter_50_Clouds.pdf
#   - Saving: Chapter 51: Arsenal → Chapter_75_Chapter_51_Arsenal.pdf
#   - Saving: Chapter 52: Mass → Chapter_76_Chapter_52_Mass.pdf
#   - Saving: Chapter 53: Motion → Chapter_77_Chapter_53_Motion.pdf
#   - Saving: Chapter 54: Animus → Chapter_78_Chapter_54_Animus.pdf
#   - Saving: Interlude: Reputation → Chapter_79_Interlude_Reputation.pdf
#   - Saving: Interlude: Honour → Chapter_80_Interlude_Honour.pdf
#   - Saving: Chapter 55: Hail → Chapter_81_Chapter_55_Hail.pdf
#   - Saving: Chapter 56: Brink → Chapter_82_Chapter_56_Brink.pdf
#   - Saving: Interlude: Calls → Chapter_83_Interlude_Calls.pdf
#   - Saving: Chapter 57: Dawn → Chapter_84_Chapter_57_Dawn.pdf
#   - Saving: Chapter 58: Mud → Chapter_85_Chapter_58_Mud.pdf
#   - Saving: Chapter 59: Steel → Chapter_86_Chapter_59_Steel.pdf
#   - Saving: Chapter 60: Blood → Chapter_87_Chapter_60_Blood.pdf
#   - Saving: Chapter 61: Break → Chapter_88_Chapter_61_Break.pdf
#   - Saving: Chapter 62: Finish → Chapter_89_Chapter_62_Finish.pdf
#   - Saving: Chapter 63: Farewell → Chapter_90_Chapter_63_Farewell.pdf
#   - Saving: Interlude: Legends I → Chapter_91_Interlude_Legends_I.pdf
#   - Saving: Interlude: Legends II → Chapter_92_Interlude_Legends_II.pdf
#   - Saving: Interlude: Legends III → Chapter_93_Interlude_Legends_III.pdf
#   - Saving: Interlude: Legends IV → Chapter_94_Interlude_Legends_IV.pdf
#   - Saving: Chapter 64: Gehenna → Chapter_95_Chapter_64_Gehenna.pdf
#   - Saving: Chapter 65: Monster → Chapter_96_Chapter_65_Monster.pdf
#   - Saving: Chapter 66: The Empty Grave → Chapter_97_Chapter_66_The_Empty_Grave.pdf
#   - Saving: Chapter 67: And Justice For All (Redux) → Chapter_98_Chapter_67_And_Justice_For_All_Redux.pdf
#   - Saving: Interlude: Legends V → Chapter_99_Interlude_Legends_V.pdf
#   - Saving: Chapter 68: Hallow; Hollow → Chapter_100_Chapter_68_Hallow_Hollow.pdf
#   - Saving: Epilogue I → Chapter_101_Epilogue_I.pdf
#   - Saving: Epilogue II → Chapter_102_Epilogue_II.pdf
