# %% [markdown]
# barnes-maze-starter/
# ├── index.html
# ├── package.json
# ├── tsconfig.json
# ├── vite.config.ts
# ├── README.md
# └── src/
#     ├── App.tsx
#     ├── main.tsx
#     ├── styles.css
#     │
#     ├── models/
#     │   └── media.ts
#     │
#     ├── video/
#     │   ├── decoderClient.ts
#     │   ├── messages.ts
#     │   ├── time.ts
#     │   └── time.test.ts
#     │
#     └── workers/
#         └── videoDecoder.worker.ts
